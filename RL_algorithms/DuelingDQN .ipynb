# %% [markdown]
# # Unity ML Agents
# ## Environment Basics
# This notebook contains a walkthrough of the basic functions of the Python API for Unity ML Agents. For instructions on building a Unity environment, see [here](https://github.com/Unity-Technologies/ml-agents/wiki/Getting-Started-with-Balance-Ball).

# %% [markdown]
# ### 1. Load dependencies

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import cv2
import random
import datetime
import os
import time

from unityagents import UnityEnvironment

# %matplotlib inline

# %% [markdown]
# ### 2. Set environment parameters
#
# Be sure to set `env_name` to the name of the Unity environment file you want to launch.

# %%
env_name = "./ML_Agent_VehicleSimulator/ML_Agent_VehicleSimulator_static" # Name of the Unity environment binary to launch
train_mode = True # Whether to run the environment in training or inference mode

# %% [markdown]
# ### 3. Start the environment
# `UnityEnvironment` launches and begins communication with the environment when instantiated.
#
# Environments contain _brains_ which are responsible for deciding the actions of their associated _agents_. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
env = UnityEnvironment(file_name=env_name)

# Examine environment parameters
print(str(env))

# Set the default brain to work with
default_brain = env.brain_names[0]
brain = env.brains[default_brain]
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of brains: 1
#         Reset Parameters :
#
# Unity brain name: Brain
#         Number of observations (per agent): 1
#         State space type: discrete
#         State space size (per agent): 1
#         Action space type: discrete
#         Action space size (per agent): 3
#         Memory space size (per agent): 0
#         Action descriptions: a, d, s

# %% [markdown]
# ### 4. Examine the observation and state spaces
# We can reset the environment to be provided with an initial set of observations and states for all the agents within the environment. In ML-Agents, _states_ refer to a vector of variables corresponding to relevant aspects of the environment for an agent. Likewise, _observations_ refer to a set of relevant pixel-wise visuals for an agent.

# %%
# Reset the environment
env_info = env.reset(train_mode=train_mode)[default_brain]

# Examine the state space for the default brain
print("Agent state looks like: \n{}".format(env_info.states[0]))

# Examine the observation space for the default brain
Num_obs = len(env_info.observations)

print("Agent observations look like:")
if Num_obs > 1:
    f, axarr = plt.subplots(1, Num_obs, figsize=(20,10))
    for i, observation in enumerate(env_info.observations):
        if observation.shape[3] == 3:
            axarr[i].imshow(observation[0,:,:,:])
            axarr[i].axis('off')
        else:
            axarr[i].imshow(observation[0,:,:,0])
            axarr[i].axis('off')
else:
    f, axarr = plt.subplots(1, Num_obs)
    for i, observation in enumerate(env_info.observations):
        if observation.shape[3] == 3:
            axarr.imshow(observation[0,:,:,:])
            axarr.axis('off')
        else:
            axarr.imshow(observation[0,:,:,0])
            axarr.axis('off')
# Out:
# Agent state looks like:
# [ 0.]
# Agent observations look like:

# %% [markdown]
# ### 5. Parameters

# %%
import random

Gamma = 0.99
Learning_rate = 0.00025

algorithm = 'DuelingDQN'
Num_action = brain.action_space_size

Num_replay_memory = 50000
Num_start_training = 25000
Num_training = 500000
Num_update = 5000
Num_batch = 32
Num_test = 100000
Num_skipFrame = 4
Num_stackFrame = 4
Num_colorChannel = 1

Epsilon = 1.0
Final_epsilon = 0.1

Num_plot_episode = 20
Num_step_save = 50000

GPU_fraction = 0.3

img_size = 80

first_conv   = [8,8,Num_colorChannel * Num_stackFrame * Num_obs,32]
second_conv  = [4,4,32,64]
third_conv   = [3,3,64,64]
first_dense  = [10*10*64, 512]
second_dense_state  = [first_dense[1], 1]
second_dense_action = [first_dense[1], Num_action]

train_mode = True
env_info = env.reset(train_mode=train_mode)[default_brain]
state = env_info.states[0]
state = str(state)

score_list = []
check_show_progress = 0

# %% [markdown]
# ### Functions for Networks

# %%
# Initialize weights and bias
def weight_variable(shape):
    return tf.Variable(xavier_initializer(shape))

def bias_variable(shape):
	return tf.Variable(xavier_initializer(shape))

def mu_variable(shape):
    return tf.Variable(tf.random_uniform(shape, minval = -tf.sqrt(3/shape[0]), maxval = tf.sqrt(3/shape[0])))

def sigma_variable(shape):
	return tf.Variable(tf.constant(0.017, shape = shape))

# Xavier Weights initializer
def xavier_initializer(shape):
	dim_sum = np.sum(shape)
	if len(shape) == 1:
		dim_sum += 1
	bound = np.sqrt(2.0 / dim_sum)
	return tf.random_uniform(shape, minval=-bound, maxval=bound)

# Convolution and pooling
def conv2d(x,w, stride):
	return tf.nn.conv2d(x,w,strides=[1, stride, stride, 1], padding='SAME')

def max_pool_2x2(x):
	return tf.nn.max_pool(x, ksize=[1,2,2,1], strides=[1,2,2,1], padding='SAME')

def assign_network_to_target():
	# Get trainable variables
	trainable_variables = tf.trainable_variables()
	# network lstm variables
	trainable_variables_network = [var for var in trainable_variables if var.name.startswith('network')]

	# target lstm variables
	trainable_variables_target = [var for var in trainable_variables if var.name.startswith('target')]

	for i in range(len(trainable_variables_network)):
		sess.run(tf.assign(trainable_variables_target[i], trainable_variables_network[i]))

# Code for tensorboard
def setup_summary():
    episode_score   = tf.Variable(0.)

    tf.summary.scalar('Average_Score/' + str(Num_plot_episode) + 'episodes', episode_score)

    summary_vars = [episode_score]
    summary_placeholders = [tf.placeholder(tf.float32) for _ in range(len(summary_vars))]
    update_ops = [summary_vars[i].assign(summary_placeholders[i]) for i in range(len(summary_vars))]
    summary_op = tf.summary.merge_all()
    return summary_placeholders, update_ops, summary_op

# %% [markdown]
# ### Network

# %%
# Input
x_image = tf.placeholder(tf.float32, shape = [None, img_size, img_size, Num_colorChannel * Num_stackFrame * Num_obs])
x_normalize = (x_image - (255.0/2)) / (255.0/2)

with tf.variable_scope('network'):
	# Convolution variables
	w_conv1 = weight_variable(first_conv)
	b_conv1 = bias_variable([first_conv[3]])

	w_conv2 = weight_variable(second_conv)
	b_conv2 = bias_variable([second_conv[3]])

	w_conv3 = weight_variable(third_conv)
	b_conv3 = bias_variable([third_conv[3]])

	# Densely connect layer variables
	w_fc1_1 = weight_variable(first_dense)
	b_fc1_1 = bias_variable([first_dense[1]])

	w_fc1_2 = weight_variable(first_dense)
	b_fc1_2 = bias_variable([first_dense[1]])

	w_fc2_1 = weight_variable(second_dense_state)
	b_fc2_1 = bias_variable([second_dense_state[1]])

	w_fc2_2 = weight_variable(second_dense_action)
	b_fc2_2 = bias_variable([second_dense_action[1]])

# Network
h_conv1 = tf.nn.relu(conv2d(x_normalize, w_conv1, 4) + b_conv1)
h_conv2 = tf.nn.relu(conv2d(h_conv1, w_conv2, 2) + b_conv2)
h_conv3 = tf.nn.relu(conv2d(h_conv2, w_conv3, 1) + b_conv3)

h_pool3_flat = tf.reshape(h_conv3, [-1, first_dense[0]])
h_fc1_state  = tf.nn.relu(tf.matmul(h_pool3_flat, w_fc1_1)+b_fc1_1)
h_fc1_action = tf.nn.relu(tf.matmul(h_pool3_flat, w_fc1_2)+b_fc1_2)

h_fc2_state  = tf.matmul(h_fc1_state,  w_fc2_1)+b_fc2_1
h_fc2_action = tf.matmul(h_fc1_action, w_fc2_2)+b_fc2_2

h_fc2_advantage = tf.subtract(h_fc2_action, tf.reduce_mean(h_fc2_action))

output = tf.add(h_fc2_state, h_fc2_advantage)

with tf.variable_scope('target'):
	# Convolution variables target
	w_conv1_target = weight_variable(first_conv)
	b_conv1_target = bias_variable([first_conv[3]])

	w_conv2_target = weight_variable(second_conv)
	b_conv2_target = bias_variable([second_conv[3]])

	w_conv3_target = weight_variable(third_conv)
	b_conv3_target = bias_variable([third_conv[3]])

	# Densely connect layer variables target
	w_fc1_1_target = weight_variable(first_dense)
	b_fc1_1_target = bias_variable([first_dense[1]])

	w_fc1_2_target = weight_variable(first_dense)
	b_fc1_2_target = bias_variable([first_dense[1]])

	w_fc2_1_target = weight_variable(second_dense_state)
	b_fc2_1_target = bias_variable([second_dense_state[1]])

	w_fc2_2_target = weight_variable(second_dense_action)
	b_fc2_2_target = bias_variable([second_dense_action[1]])

# Target Network
h_conv1_target = tf.nn.relu(conv2d(x_normalize, w_conv1_target, 4) + b_conv1_target)
h_conv2_target = tf.nn.relu(conv2d(h_conv1_target, w_conv2_target, 2) + b_conv2_target)
h_conv3_target = tf.nn.relu(conv2d(h_conv2_target, w_conv3_target, 1) + b_conv3_target)

h_pool3_flat_target = tf.reshape(h_conv3_target, [-1, first_dense[0]])

h_fc1_state_target  = tf.nn.relu(tf.matmul(h_pool3_flat_target, w_fc1_1_target)+b_fc1_1_target)
h_fc1_action_target = tf.nn.relu(tf.matmul(h_pool3_flat_target, w_fc1_2_target)+b_fc1_2_target)

h_fc2_state_target  = tf.matmul(h_fc1_state_target,  w_fc2_1_target)+b_fc2_1_target
h_fc2_action_target = tf.matmul(h_fc1_action_target, w_fc2_2_target)+b_fc2_2_target

h_fc2_advantage_target = tf.subtract(h_fc2_action_target, tf.reduce_mean(h_fc2_action_target))

output_target = tf.add(h_fc2_state_target, h_fc2_advantage_target)

# %% [markdown]
# ### Loss

# %%
# Loss function and Train
action_target = tf.placeholder(tf.float32, shape = [None, Num_action])
y_target = tf.placeholder(tf.float32, shape = [None])

y_prediction = tf.reduce_sum(tf.multiply(output, action_target), reduction_indices = 1)
Loss = tf.reduce_mean(tf.square(y_prediction - y_target))
train_step = tf.train.AdamOptimizer(learning_rate = Learning_rate, epsilon = 1e-02).minimize(Loss)

# %% [markdown]
# ### Config

# %%
## Initialize variables
config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = GPU_fraction

sess = tf.InteractiveSession(config=config)

# date - hour - minute of training time
date_time = str(datetime.date.today()) + '_' + str(datetime.datetime.now().hour) + '_' + str(datetime.datetime.now().minute)

# Make folder for save data
os.makedirs('saved_networks/' + date_time + '_' + algorithm)

# Summary for tensorboard
summary_placeholders, update_ops, summary_op = setup_summary()
summary_writer = tf.summary.FileWriter('saved_networks/' + date_time + '_' + algorithm, sess.graph)

init = tf.global_variables_initializer()
sess.run(init)

# Load the file if the saved file exists
saver = tf.train.Saver()

# check_save = 1
check_save = input('Is there any saved data?(1=y/2=n): ')

if check_save == 1:
    # Restore variables from disk.
    saver.restore(sess, 'saved_networks/' + date_time + '_' + algorithm + "/model.ckpt")
    print("Model restored.")
# Out:
# Is there any saved data?(1=y/2=n): 2

# %% [markdown]
# ### Functions for Training

# %%
# Initialize_input
def input_initialization(env_info):
    observation_stack_obs = np.zeros([img_size, img_size, Num_colorChannel * Num_obs])
    
    for i in range(Num_obs):
        observation = 255 * env_info.observations[i]
        observation = np.uint8(observation)
        observation = np.reshape(observation, (80, 80, 3))
        observation = cv2.resize(observation, (img_size, img_size))

        if Num_colorChannel == 1:
            observation = cv2.cvtColor(observation, cv2.COLOR_RGB2GRAY)
            observation = np.reshape(observation, (img_size, img_size))

        if Num_colorChannel == 3:
            observation_stack_obs[:,:, Num_colorChannel * i: Num_colorChannel * (i+1)] = observation
        else:
            observation_stack_obs[:,:, i] = observation

    observation_set = []

    for i in range(Num_skipFrame * Num_stackFrame):
        observation_set.append(observation_stack_obs)
    
    # Stack the frame according to the number of skipping and stacking frames using observation set
    observation_stack = np.zeros((img_size, img_size, Num_colorChannel * Num_stackFrame * Num_obs))
    for stack_frame in range(Num_stackFrame):
        observation_stack[:,:,Num_obs * stack_frame: Num_obs * (stack_frame+1)] = observation_set[-1 - (Num_skipFrame * stack_frame)]

    observation_stack = np.uint8(observation_stack)

    return observation_stack, observation_set

def resize_input(env_info, observation_set):
    # Stack observation according to the number of observations
    observation_stack_obs = np.zeros([img_size, img_size, Num_colorChannel * Num_obs])

    for i in range(Num_obs):
        observation = 255 * env_info.observations[i]
        observation = np.uint8(observation)
        observation = np.reshape(observation, (80, 80, 3))
        observation = cv2.resize(observation, (img_size, img_size))
        
        if Num_colorChannel == 1:
            observation = cv2.cvtColor(observation, cv2.COLOR_RGB2GRAY)
            observation = np.reshape(observation, (img_size, img_size))

        if Num_colorChannel == 3:
            observation_stack_obs[:,:, Num_colorChannel * i: Num_colorChannel * (i+1)] = observation
        else:
            observation_stack_obs[:,:,i] = observation
    
    # Add observations to the observation_set
    observation_set.append(observation_stack_obs)
    
    # Stack the frame according to the number of skipping and stacking frames using observation set
    observation_stack = np.zeros((img_size, img_size, Num_colorChannel * Num_stackFrame * Num_obs))
    for stack_frame in range(Num_stackFrame):
        observation_stack[:,:,Num_obs * stack_frame: Num_obs * (stack_frame+1)] = observation_set[-1 - (Num_skipFrame * stack_frame)]

    del observation_set[0]

    observation_stack = np.uint8(observation_stack)
    
    return observation_stack, observation_set

# Get progress according to the 
def get_progress(step, Epsilon):
    if step <= Num_start_training:
        # Observation
        progress = 'Observing'
        train_mode = True
        Epsilon = 1

    elif step <= Num_start_training + Num_training:
        # Training
        progress = 'Training'
        train_mode = True
        
        # Decrease the epsilon value
        if Epsilon > Final_epsilon:
            Epsilon -= 1.0/Num_training
        
    elif step < Num_start_training + Num_training + Num_test:
        # Testing
        progress = 'Testing'
        train_mode = False
        Epsilon = 0

    else:
        # Finished
        progress = 'Finished'
        train_mode = False
        Epsilon = 0
        
    return progress, train_mode, Epsilon 

# Select action according to the progress of training
def select_action(progress, sess, observation_stack, Epsilon):
    if progress == "Observing":
        Q_value = 0
        action = np.zeros([Num_action])
        action[random.randint(0, Num_action - 1)] = 1.0
    elif progress == "Training":
        # if random value(0 - 1) is smaller than Epsilon, action is random. Otherwise, action is the one which has the largest Q value
        if random.random() < Epsilon:
            Q_value = 0
            action = np.zeros([Num_action])
            action[random.randint(0, Num_action - 1)] = 1
        else:
            Q_value = output.eval(feed_dict={x_image: [observation_stack]})
            action = np.zeros([Num_action])
            action[np.argmax(Q_value)] = 1
    else:
        Q_value = output.eval(feed_dict={x_image: [observation_stack]})
        action = np.zeros([Num_action])
        action[np.argmax(Q_value)] = 1
        
    return action, Q_value

def train(Replay_memory, sess, step):
    # Select minibatch
    minibatch =  random.sample(Replay_memory, Num_batch)

    # Save the each batch data
    observation_batch      = [batch[0] for batch in minibatch]
    action_batch           = [batch[1] for batch in minibatch]
    reward_batch           = [batch[2] for batch in minibatch]
    observation_next_batch = [batch[3] for batch in minibatch]
    terminal_batch 	       = [batch[4] for batch in minibatch]

    # Update target network according to the Num_update value
    if step % Num_update == 0:
        assign_network_to_target()

    ########################################### Noisy Network ###########################################
    # Get y_prediction
    y_batch = []
    Q_batch = output_target.eval(feed_dict = {x_image: observation_next_batch})
    for i in range(len(minibatch)):
        if terminal_batch[i] == True:
            y_batch.append(reward_batch[i])
        else:
            y_batch.append(reward_batch[i] + Gamma * np.max(Q_batch[i]))

    _, loss = sess.run([train_step, Loss], feed_dict = {action_target: action_batch, y_target: y_batch, x_image: observation_batch})
    #####################################################################################################

# Experience Replay 
def Experience_Replay(progress, Replay_memory, observation_stack, action, reward, next_observation_stack, terminal):
    if progress != 'Testing':
        # If length of replay memeory is more than the setting value then remove the first one
        if len(Replay_memory) > Num_replay_memory:
            del Replay_memory[0]

        # Save experience to the Replay memory
        Replay_memory.append([observation_stack, action, reward, next_observation_stack, terminal])
    else:
        # Empty the replay memory if testing
        Replay_memory = []
    
    return Replay_memory

# %% [markdown]
# ### Initialize Variables

# %%
# Initial parameters
Replay_memory = []
step = 1
score = 0
score_board = 0

episode = 0
step_per_episode = 0

train_mode = True
env_info = env.reset(train_mode=train_mode)[default_brain]

observation_stack, observation_set = input_initialization(env_info)

# %% [markdown]
# ### Training

# %%
check_plot = 0

# Training & Testing
while True:
    
    # Get Progress, train mode
    progress, train_mode, Epsilon  = get_progress(step, Epsilon)
    
    # Select Actions 
    action, Q_value = select_action(progress, sess, observation_stack, Epsilon)
    action_in = [np.argmax(action)]

    # Get information for update
    env_info = env.step(action_in)[default_brain]

    next_observation_stack, observation_set = resize_input(env_info, observation_set) 
    reward = env_info.rewards[0]
    terminal = env_info.local_done[0]
    
    if progress == 'Training':
        # Train!! 
        train(Replay_memory, sess, step)

        # Save the variables to disk.
        if step == Num_start_training + Num_training:
            save_path = saver.save(sess, 'saved_networks/' + date_time + '_' + algorithm + "/model.ckpt")
            print("Model saved in file: %s" % save_path)
    
    # If progress is finished -> close! 
    if progress == 'Finished':
        print('Finished!!')
        env.close()
        break
        
    Replay_memory = Experience_Replay(progress, Replay_memory, observation_stack, action, reward, next_observation_stack, terminal)
    
    # Update information
    step += 1
    score += reward
    step_per_episode += 1
    observation_stack = next_observation_stack
    
    # Update tensorboard
    if progress != 'Observing':
        if episode % Num_plot_episode == 0 and check_plot == 1 and episode != 0:
            tensorboard_info = [score_board / Num_plot_episode]
            for i in range(len(tensorboard_info)):
                sess.run(update_ops[i], feed_dict = {summary_placeholders[i]: float(tensorboard_info[i])})
            summary_str = sess.run(summary_op)
            summary_writer.add_summary(summary_str, step)
            score_board = 0
            check_plot = 0
            
    # If terminal is True
    if terminal == True:
        # Print informations
        print('step: ' + str(step) + ' / '  + 'episode: ' + str(episode) + ' / ' + 'progress: ' + progress  + ' / ' + 'epsilon: ' + str(Epsilon)  +' / ' + 'score: ' + str(score))

        check_plot = 1

        if progress != 'Observing':
            episode += 1
            
            score_board += score
            
        score = 0
        step_per_episode = 0

        # Initialize game state
        env_info = env.reset(train_mode=train_mode)[default_brain]
        observation_stack, observation_set = input_initialization(env_info)
# Out:
# step: 143 / episode: 0 / progress: Observing / epsilon: 1 / score: 6.128571511599995
# step: 318 / episode: 0 / progress: Observing / epsilon: 1 / score: 6.950000130799996
# step: 492 / episode: 0 / progress: Observing / epsilon: 1 / score: 8.100000092600006
# step: 734 / episode: 0 / progress: Observing / epsilon: 1 / score: 12.285714343799974
# step: 1019 / episode: 0 / progress: Observing / epsilon: 1 / score: 13.471428716599995
# step: 1201 / episode: 0 / progress: Observing / epsilon: 1 / score: 10.485714310999994
# step: 1405 / episode: 0 / progress: Observing / epsilon: 1 / score: 6.364285782599989
# step: 1631 / episode: 0 / progress: Observing / epsilon: 1 / score: 8.21428580039997
# step: 1761 / episode: 0 / progress: Observing / epsilon: 1 / score: 3.9428572230999954
# step: 1942 / episode: 0 / progress: Observing / epsilon: 1 / score: 6.242857220699992
# step: 2079 / episode: 0 / progress: Observing / epsilon: 1 / score: 2.678571497399994
# step: 2381 / episode: 0 / progress: Observing / epsilon: 1 / score: 14.928571503399972
# step: 2517 / episode: 0 / progress: Observing / epsilon: 1 / score: 4.650000094099998
# step: 2720 / episode: 0 / progress: Observing / epsilon: 1 / score: 8.928571559700002
# step: 2945 / episode: 0 / progress: Observing / epsilon: 1 / score: 9.000000034899985
# step: 3166 / episode: 0 / progress: Observing / epsilon: 1 / score: 9.99285719449999
# step: 3538 / episode: 0 / progress: Observing / epsilon: 1 / score: 18.385714458599967
# step: 4009 / episode: 0 / progress: Observing / epsilon: 1 / score: 23.764285887099966
# step: 4121 / episode: 0 / progress: Observing / epsilon: 1 / score: 3.350000063499997
# step: 4250 / episode: 0 / progress: Observing / epsilon: 1 / score: 4.364285771899991
# step: 4384 / episode: 0 / progress: Observing / epsilon: 1 / score: 6.057142942099999
# step: 4581 / episode: 0 / progress: Observing / epsilon: 1 / score: 7.971428651999986
# step: 4734 / episode: 0 / progress: Observing / epsilon: 1 / score: 6.985714400299996
# step: 4854 / episode: 0 / progress: Observing / epsilon: 1 / score: 5.4357143865999955
# step: 5056 / episode: 0 / progress: Observing / epsilon: 1 / score: 8.335714409299976
# step: 5293 / episode: 0 / progress: Observing / epsilon: 1 / score: 9.278571570799986
# step: 5482 / episode: 0 / progress: Observing / epsilon: 1 / score: 6.785714416899998
# step: 6014 / episode: 0 / progress: Observing / epsilon: 1 / score: 27.657142882599892
# step: 6137 / episode: 0 / progress: Observing / epsilon: 1 / score: 4.442857224399999
# step: 6292 / episode: 0 / progress: Observing / epsilon: 1 / score: 8.935714254599988
# step: 6406 / episode: 0 / progress: Observing / epsilon: 1 / score: 3.057142910099997
# step: 6580 / episode: 0 / progress: Observing / epsilon: 1 / score: 7.971428707999998
# step: 6713 / episode: 0 / progress: Observing / epsilon: 1 / score: 2.864285798800001
# step: 7088 / episode: 0 / progress: Observing / epsilon: 1 / score: 18.442857362799987
# step: 7212 / episode: 0 / progress: Observing / epsilon: 1 / score: 3.250000062799998
# step: 7670 / episode: 0 / progress: Observing / epsilon: 1 / score: 22.978571693100005
# step: 7785 / episode: 0 / progress: Observing / epsilon: 1 / score: 5.6642857987999955
# step: 7931 / episode: 0 / progress: Observing / epsilon: 1 / score: 3.6928572176999968
# step: 8335 / episode: 0 / progress: Observing / epsilon: 1 / score: 19.24285730019998
# step: 8543 / episode: 0 / progress: Observing / epsilon: 1 / score: 9.614285705699986
# step: 8657 / episode: 0 / progress: Observing / epsilon: 1 / score: 2.8214286326999973
# step: 8773 / episode: 0 / progress: Observing / epsilon: 1 / score: 4.771428654799997
# step: 8961 / episode: 0 / progress: Observing / epsilon: 1 / score: 8.857142958000004
# step: 9159 / episode: 0 / progress: Observing / epsilon: 1 / score: 6.164285727899994
# step: 9584 / episode: 0 / progress: Observing / epsilon: 1 / score: 23.085714291999977
# step: 10072 / episode: 0 / progress: Observing / epsilon: 1 / score: 24.71428586109996
# step: 10442 / episode: 0 / progress: Observing / epsilon: 1 / score: 17.014285939700024
# step: 10647 / episode: 0 / progress: Observing / epsilon: 1 / score: 11.985714246699981
# step: 10841 / episode: 0 / progress: Observing / epsilon: 1 / score: 10.035714436600012
# step: 10981 / episode: 0 / progress: Observing / epsilon: 1 / score: 3.221428650700002
# step: 11207 / episode: 0 / progress: Observing / epsilon: 1 / score: 7.607142920399976
# step: 11521 / episode: 0 / progress: Observing / epsilon: 1 / score: 15.592857212899968
# step: 11824 / episode: 0 / progress: Observing / epsilon: 1 / score: 16.350000114699974
# step: 12026 / episode: 0 / progress: Observing / epsilon: 1 / score: 6.842857233999993
# step: 12209 / episode: 0 / progress: Observing / epsilon: 1 / score: 7.9571428231999946
# step: 12639 / episode: 0 / progress: Observing / epsilon: 1 / score: 24.350000057599882
# step: 13165 / episode: 0 / progress: Observing / epsilon: 1 / score: 27.31428574569992
# step: 13367 / episode: 0 / progress: Observing / epsilon: 1 / score: 9.242857169299988
# step: 13490 / episode: 0 / progress: Observing / epsilon: 1 / score: 5.5428572081
# step: 13802 / episode: 0 / progress: Observing / epsilon: 1 / score: 13.849999945799963
# step: 13937 / episode: 0 / progress: Observing / epsilon: 1 / score: 4.2285715279
# step: 14065 / episode: 0 / progress: Observing / epsilon: 1 / score: 3.2642857779999943
# step: 14252 / episode: 0 / progress: Observing / epsilon: 1 / score: 8.485714423799992
# step: 14365 / episode: 0 / progress: Observing / epsilon: 1 / score: 3.3428572053999996
# step: 14595 / episode: 0 / progress: Observing / epsilon: 1 / score: 8.21428577579998
# step: 14738 / episode: 0 / progress: Observing / epsilon: 1 / score: 4.9071429166
# step: 14922 / episode: 0 / progress: Observing / epsilon: 1 / score: 9.171428700799998
# step: 15296 / episode: 0 / progress: Observing / epsilon: 1 / score: 17.97142858229991
# step: 15506 / episode: 0 / progress: Observing / epsilon: 1 / score: 6.585714381699985
# step: 15656 / episode: 0 / progress: Observing / epsilon: 1 / score: 4.678571478199992
# step: 15822 / episode: 0 / progress: Observing / epsilon: 1 / score: 5.978571502599993
# step: 16039 / episode: 0 / progress: Observing / epsilon: 1 / score: 8.964285805999994
# step: 16198 / episode: 0 / progress: Observing / epsilon: 1 / score: 5.414285791399994
# step: 16415 / episode: 0 / progress: Observing / epsilon: 1 / score: 10.957142849799986
# step: 16599 / episode: 0 / progress: Observing / epsilon: 1 / score: 8.600000143899992
# step: 16714 / episode: 0 / progress: Observing / epsilon: 1 / score: 3.821428612
# step: 16915 / episode: 0 / progress: Observing / epsilon: 1 / score: 7.1285715275999895
# step: 17134 / episode: 0 / progress: Observing / epsilon: 1 / score: 11.55000017720001
# step: 17255 / episode: 0 / progress: Observing / epsilon: 1 / score: 4.385714357799997
# step: 17408 / episode: 0 / progress: Observing / epsilon: 1 / score: 4.157142872300003
# step: 17872 / episode: 0 / progress: Observing / epsilon: 1 / score: 28.357143022600034
# step: 18046 / episode: 0 / progress: Observing / epsilon: 1 / score: 6.635714404099987
# step: 18430 / episode: 0 / progress: Observing / epsilon: 1 / score: 16.035714306600003
# step: 19166 / episode: 0 / progress: Observing / epsilon: 1 / score: 34.49285742389986
# step: 19345 / episode: 0 / progress: Observing / epsilon: 1 / score: 10.228571430299993
# step: 19565 / episode: 0 / progress: Observing / epsilon: 1 / score: 7.742857236299997
# step: 19677 / episode: 0 / progress: Observing / epsilon: 1 / score: 2.6000000823000002
# step: 19878 / episode: 0 / progress: Observing / epsilon: 1 / score: 11.692857296999994
# step: 20106 / episode: 0 / progress: Observing / epsilon: 1 / score: 8.778571559099973
# step: 20283 / episode: 0 / progress: Observing / epsilon: 1 / score: 6.278571500199986
# step: 20747 / episode: 0 / progress: Observing / epsilon: 1 / score: 21.607143134599994
# step: 21131 / episode: 0 / progress: Observing / epsilon: 1 / score: 18.585714484500034
# step: 21321 / episode: 0 / progress: Observing / epsilon: 1 / score: 9.785714422199993
# step: 21693 / episode: 0 / progress: Observing / epsilon: 1 / score: 18.278571550199963
# step: 22024 / episode: 0 / progress: Observing / epsilon: 1 / score: 15.86428588259998
# step: 22214 / episode: 0 / progress: Observing / epsilon: 1 / score: 8.450000087699998
# step: 22414 / episode: 0 / progress: Observing / epsilon: 1 / score: 8.314285833399978
# step: 22567 / episode: 0 / progress: Observing / epsilon: 1 / score: 7.928571535999994
# step: 23010 / episode: 0 / progress: Observing / epsilon: 1 / score: 17.98571436670002
# step: 23212 / episode: 0 / progress: Observing / epsilon: 1 / score: 6.100000016299994
# step: 23746 / episode: 0 / progress: Observing / epsilon: 1 / score: 36.7500000188999
# step: 23889 / episode: 0 / progress: Observing / epsilon: 1 / score: 5.221428628199998
# step: 24101 / episode: 0 / progress: Observing / epsilon: 1 / score: 6.57142865189998
# step: 24288 / episode: 0 / progress: Observing / epsilon: 1 / score: 9.250000095399988
# step: 24500 / episode: 0 / progress: Observing / epsilon: 1 / score: 5.56428580729999
# step: 24905 / episode: 0 / progress: Observing / epsilon: 1 / score: 19.764285856900038
# step: 25025 / episode: 0 / progress: Training / epsilon: 0.9999520000000013 / score: 2.992857197899993
# step: 25412 / episode: 1 / progress: Training / epsilon: 0.999178000000022 / score: 18.207143089899958
# step: 25693 / episode: 2 / progress: Training / epsilon: 0.998616000000037 / score: 19.321428689999998
# step: 25821 / episode: 3 / progress: Training / epsilon: 0.9983600000000439 / score: 6.035714390900001
# step: 25960 / episode: 4 / progress: Training / epsilon: 0.9980820000000513 / score: 3.778571498099992
# step: 26361 / episode: 5 / progress: Training / epsilon: 0.9972800000000728 / score: 21.764285770799923
# step: 26491 / episode: 6 / progress: Training / epsilon: 0.9970200000000797 / score: 6.057142921499995
# step: 26671 / episode: 7 / progress: Training / epsilon: 0.9966600000000894 / score: 6.357142935899992
# step: 27040 / episode: 8 / progress: Training / epsilon: 0.9959220000001091 / score: 19.578571535500004
# step: 27196 / episode: 9 / progress: Training / epsilon: 0.9956100000001175 / score: 7.492857208199995
# step: 27355 / episode: 10 / progress: Training / epsilon: 0.995292000000126 / score: 6.135714350899997
# step: 27553 / episode: 11 / progress: Training / epsilon: 0.9948960000001366 / score: 5.985714365099985
# step: 27816 / episode: 12 / progress: Training / epsilon: 0.9943700000001506 / score: 10.535714432599976
# step: 27934 / episode: 13 / progress: Training / epsilon: 0.994134000000157 / score: 3.792857218999999
# step: 28072 / episode: 14 / progress: Training / epsilon: 0.9938580000001643 / score: 4.42142862879999
# step: 28289 / episode: 15 / progress: Training / epsilon: 0.9934240000001759 / score: 9.15000009039999
# step: 28475 / episode: 16 / progress: Training / epsilon: 0.9930520000001859 / score: 6.778571454699982
# step: 28679 / episode: 17 / progress: Training / epsilon: 0.9926440000001968 / score: 6.935714408599981
# step: 28812 / episode: 18 / progress: Training / epsilon: 0.9923780000002039 / score: 5.607142956699994
# step: 28935 / episode: 19 / progress: Training / epsilon: 0.9921320000002105 / score: 3.0714285942999986
# step: 29432 / episode: 20 / progress: Training / epsilon: 0.9911380000002371 / score: 20.278571487999937
# step: 29580 / episode: 21 / progress: Training / epsilon: 0.990842000000245 / score: 4.407142906899997
# step: 30074 / episode: 22 / progress: Training / epsilon: 0.9898540000002715 / score: 25.40714311060006
# step: 30266 / episode: 23 / progress: Training / epsilon: 0.9894700000002817 / score: 7.46428573709999
# step: 30611 / episode: 24 / progress: Training / epsilon: 0.9887800000003002 / score: 16.5285715831
# step: 30730 / episode: 25 / progress: Training / epsilon: 0.9885420000003066 / score: 2.8642857833999926
# step: 30859 / episode: 26 / progress: Training / epsilon: 0.9882840000003135 / score: 4.985714376999999
# step: 31083 / episode: 27 / progress: Training / epsilon: 0.9878360000003255 / score: 10.850000114099995
# step: 31240 / episode: 28 / progress: Training / epsilon: 0.9875220000003339 / score: 7.607142991199996
# step: 31393 / episode: 29 / progress: Training / epsilon: 0.987216000000342 / score: 8.342857246200001
# step: 32067 / episode: 30 / progress: Training / epsilon: 0.9858680000003781 / score: 43.4857142009998
# step: 32471 / episode: 31 / progress: Training / epsilon: 0.9850600000003997 / score: 18.57142859219991
# step: 32681 / episode: 32 / progress: Training / epsilon: 0.984640000000411 / score: 10.714285877699997
# step: 32876 / episode: 33 / progress: Training / epsilon: 0.9842500000004214 / score: 8.121428686499994
# step: 33000 / episode: 34 / progress: Training / epsilon: 0.984002000000428 / score: 4.7785715137999984
# step: 33195 / episode: 35 / progress: Training / epsilon: 0.9836120000004385 / score: 4.928571516299992
# step: 33432 / episode: 36 / progress: Training / epsilon: 0.9831380000004512 / score: 10.364285812599974
# step: 33618 / episode: 37 / progress: Training / epsilon: 0.9827660000004611 / score: 6.1857143623999935
# step: 33773 / episode: 38 / progress: Training / epsilon: 0.9824560000004694 / score: 7.214285824999999
# step: 33929 / episode: 39 / progress: Training / epsilon: 0.9821440000004777 / score: 3.935714370199994
# step: 34084 / episode: 40 / progress: Training / epsilon: 0.981834000000486 / score: 6.771428660599996
# step: 34297 / episode: 41 / progress: Training / epsilon: 0.9814080000004974 / score: 6.9571428946000005
# step: 34729 / episode: 42 / progress: Training / epsilon: 0.9805440000005206 / score: 21.478571387099937
# step: 34965 / episode: 43 / progress: Training / epsilon: 0.9800720000005332 / score: 15.635714295199971
# step: 35354 / episode: 44 / progress: Training / epsilon: 0.979294000000554 / score: 19.235714477100046
# step: 35572 / episode: 45 / progress: Training / epsilon: 0.9788580000005657 / score: 10.678571521399995
# step: 35690 / episode: 46 / progress: Training / epsilon: 0.978622000000572 / score: 5.242857225699995
# step: 35807 / episode: 47 / progress: Training / epsilon: 0.9783880000005782 / score: 2.7714286423999983
# step: 36412 / episode: 48 / progress: Training / epsilon: 0.9771780000006106 / score: 30.700000387800017
# step: 36608 / episode: 49 / progress: Training / epsilon: 0.9767860000006211 / score: 9.742857305100003
# step: 36835 / episode: 50 / progress: Training / epsilon: 0.9763320000006332 / score: 9.09285716909997
# step: 36983 / episode: 51 / progress: Training / epsilon: 0.9760360000006412 / score: 5.514285753799994
# step: 37437 / episode: 52 / progress: Training / epsilon: 0.9751280000006655 / score: 26.842857088899894
# step: 37646 / episode: 53 / progress: Training / epsilon: 0.9747100000006766 / score: 9.27857145979997
# step: 37766 / episode: 54 / progress: Training / epsilon: 0.9744700000006831 / score: 6.028571482399993
# step: 38114 / episode: 55 / progress: Training / epsilon: 0.9737740000007017 / score: 20.135714501699983
# step: 38308 / episode: 56 / progress: Training / epsilon: 0.9733860000007121 / score: 9.150000087099974
# step: 38912 / episode: 57 / progress: Training / epsilon: 0.9721780000007444 / score: 29.542857485900054
# step: 39070 / episode: 58 / progress: Training / epsilon: 0.9718620000007528 / score: 7.507142986199996
# step: 39236 / episode: 59 / progress: Training / epsilon: 0.9715300000007617 / score: 8.178571509299996
# step: 39459 / episode: 60 / progress: Training / epsilon: 0.9710840000007737 / score: 7.47857151599999
# step: 39926 / episode: 61 / progress: Training / epsilon: 0.9701500000007987 / score: 22.728571686599995
# step: 40149 / episode: 62 / progress: Training / epsilon: 0.9697040000008106 / score: 8.00714297499999
# step: 40342 / episode: 63 / progress: Training / epsilon: 0.9693180000008209 / score: 5.100000072299998
# step: 40555 / episode: 64 / progress: Training / epsilon: 0.9688920000008323 / score: 10.271428658399985
# step: 41201 / episode: 65 / progress: Training / epsilon: 0.9676000000008669 / score: 37.21428606459993
# step: 41383 / episode: 66 / progress: Training / epsilon: 0.9672360000008766 / score: 7.678571510399992
# step: 41591 / episode: 67 / progress: Training / epsilon: 0.9668200000008877 / score: 10.457142898500004
# step: 41782 / episode: 68 / progress: Training / epsilon: 0.966438000000898 / score: 10.735714389399991
# step: 41937 / episode: 69 / progress: Training / epsilon: 0.9661280000009063 / score: 2.9071429341999924
# step: 42159 / episode: 70 / progress: Training / epsilon: 0.9656840000009181 / score: 9.400000158400001
# step: 42316 / episode: 71 / progress: Training / epsilon: 0.9653700000009265 / score: 8.121428593999985
# step: 42492 / episode: 72 / progress: Training / epsilon: 0.965018000000936 / score: 5.500000089899994
# step: 42681 / episode: 73 / progress: Training / epsilon: 0.9646400000009461 / score: 7.207142938499988
# step: 42853 / episode: 74 / progress: Training / epsilon: 0.9642960000009553 / score: 5.800000017399995
# step: 43057 / episode: 75 / progress: Training / epsilon: 0.9638880000009662 / score: 10.857143013199995
# step: 43412 / episode: 76 / progress: Training / epsilon: 0.9631780000009852 / score: 19.985714549700056
# step: 43618 / episode: 77 / progress: Training / epsilon: 0.9627660000009962 / score: 11.092857250099994
# step: 44053 / episode: 78 / progress: Training / epsilon: 0.9618960000010195 / score: 23.935714361899954
# step: 44208 / episode: 79 / progress: Training / epsilon: 0.9615860000010278 / score: 4.342857174899993
# step: 44488 / episode: 80 / progress: Training / epsilon: 0.9610260000010428 / score: 15.164285831799965
# step: 44626 / episode: 81 / progress: Training / epsilon: 0.9607500000010502 / score: 5.4000001053999975
# step: 45029 / episode: 82 / progress: Training / epsilon: 0.9599440000010717 / score: 18.900000106699945
# step: 45337 / episode: 83 / progress: Training / epsilon: 0.9593280000010882 / score: 16.142857257599974
# step: 45510 / episode: 84 / progress: Training / epsilon: 0.9589820000010975 / score: 7.314285831999996
# step: 45813 / episode: 85 / progress: Training / epsilon: 0.9583760000011137 / score: 14.492857245499977
# step: 46029 / episode: 86 / progress: Training / epsilon: 0.9579440000011252 / score: 9.635714431299983
# step: 46164 / episode: 87 / progress: Training / epsilon: 0.9576740000011325 / score: 6.564285708799993
# step: 46560 / episode: 88 / progress: Training / epsilon: 0.9568820000011536 / score: 19.65714289179995
# step: 46782 / episode: 89 / progress: Training / epsilon: 0.9564380000011655 / score: 9.528571529299983
# step: 47279 / episode: 90 / progress: Training / epsilon: 0.9554440000011921 / score: 27.85000025849996
# step: 47398 / episode: 91 / progress: Training / epsilon: 0.9552060000011985 / score: 5.057142961100001
# step: 47914 / episode: 92 / progress: Training / epsilon: 0.9541740000012261 / score: 29.50714307010002
# step: 48182 / episode: 93 / progress: Training / epsilon: 0.9536380000012404 / score: 14.557142990799981
# step: 48389 / episode: 94 / progress: Training / epsilon: 0.9532240000012515 / score: 9.95000012989999
# step: 48505 / episode: 95 / progress: Training / epsilon: 0.9529920000012577 / score: 4.8714286233999955
# step: 48707 / episode: 96 / progress: Training / epsilon: 0.9525880000012685 / score: 11.428571473399986
# step: 48883 / episode: 97 / progress: Training / epsilon: 0.952236000001278 / score: 9.250000083399996
# step: 49181 / episode: 98 / progress: Training / epsilon: 0.9516400000012939 / score: 15.91428571119997
# step: 49512 / episode: 99 / progress: Training / epsilon: 0.9509780000013116 / score: 20.414285754599973
# step: 49650 / episode: 100 / progress: Training / epsilon: 0.950702000001319 / score: 5.542857221499995
# step: 49997 / episode: 101 / progress: Training / epsilon: 0.9500080000013376 / score: 19.842857247700007
# step: 50508 / episode: 102 / progress: Training / epsilon: 0.9489860000013649 / score: 25.678571733500082
# step: 50678 / episode: 103 / progress: Training / epsilon: 0.948646000001374 / score: 7.221428622899998
# step: 50797 / episode: 104 / progress: Training / epsilon: 0.9484080000013804 / score: 4.192857219300002
# step: 50939 / episode: 105 / progress: Training / epsilon: 0.948124000001388 / score: 5.021428656199995
# step: 51074 / episode: 106 / progress: Training / epsilon: 0.9478540000013952 / score: 5.364285788899994
# step: 51289 / episode: 107 / progress: Training / epsilon: 0.9474240000014067 / score: 12.0071430319
# step: 51472 / episode: 108 / progress: Training / epsilon: 0.9470580000014165 / score: 8.65714295689999
# step: 51977 / episode: 109 / progress: Training / epsilon: 0.9460480000014435 / score: 30.414285881099907
# step: 52287 / episode: 110 / progress: Training / epsilon: 0.9454280000014601 / score: 16.400000003000024
# step: 52484 / episode: 111 / progress: Training / epsilon: 0.9450340000014706 / score: 9.59285716899999
# step: 52859 / episode: 112 / progress: Training / epsilon: 0.9442840000014907 / score: 19.728571696399985
# step: 53196 / episode: 113 / progress: Training / epsilon: 0.9436100000015087 / score: 17.40714286989996
# step: 53339 / episode: 114 / progress: Training / epsilon: 0.9433240000015164 / score: 8.085714381800006
# step: 53673 / episode: 115 / progress: Training / epsilon: 0.9426560000015343 / score: 19.250000250800056
# step: 54051 / episode: 116 / progress: Training / epsilon: 0.9419000000015545 / score: 22.87142886810006
# step: 54384 / episode: 117 / progress: Training / epsilon: 0.9412340000015723 / score: 20.171428843600022
# step: 54547 / episode: 118 / progress: Training / epsilon: 0.940908000001581 / score: 8.442857200599997
# step: 54967 / episode: 119 / progress: Training / epsilon: 0.9400680000016035 / score: 21.278571735600046
# step: 55195 / episode: 120 / progress: Training / epsilon: 0.9396120000016157 / score: 12.242857280799992
# step: 55366 / episode: 121 / progress: Training / epsilon: 0.9392700000016249 / score: 8.59285724609999
# step: 55560 / episode: 122 / progress: Training / epsilon: 0.9388820000016352 / score: 7.307142999599977
# step: 55678 / episode: 123 / progress: Training / epsilon: 0.9386460000016416 / score: 8.328571468600003
# step: 55820 / episode: 124 / progress: Training / epsilon: 0.9383620000016492 / score: 6.514285805799995
# step: 56188 / episode: 125 / progress: Training / epsilon: 0.9376260000016688 / score: 18.164285820099913
# step: 56422 / episode: 126 / progress: Training / epsilon: 0.9371580000016814 / score: 9.91428580859999
# step: 56539 / episode: 127 / progress: Training / epsilon: 0.9369240000016876 / score: 6.057142949799998
# step: 56660 / episode: 128 / progress: Training / epsilon: 0.9366820000016941 / score: 5.149999989499996
# step: 56789 / episode: 129 / progress: Training / epsilon: 0.936424000001701 / score: 4.614285793299999
# step: 56936 / episode: 130 / progress: Training / epsilon: 0.9361300000017089 / score: 5.707142958799994
# step: 57051 / episode: 131 / progress: Training / epsilon: 0.935900000001715 / score: 4.942857209699996
# step: 57306 / episode: 132 / progress: Training / epsilon: 0.9353900000017287 / score: 11.149999970599977
# step: 57489 / episode: 133 / progress: Training / epsilon: 0.9350240000017385 / score: 10.042857202999995
# step: 57642 / episode: 134 / progress: Training / epsilon: 0.9347180000017467 / score: 5.8071429288999905
# step: 57856 / episode: 135 / progress: Training / epsilon: 0.9342900000017581 / score: 9.607142904799993
# step: 58025 / episode: 136 / progress: Training / epsilon: 0.9339520000017671 / score: 9.564285829800003
# step: 58156 / episode: 137 / progress: Training / epsilon: 0.9336900000017742 / score: 5.842857215599995
# step: 58314 / episode: 138 / progress: Training / epsilon: 0.9333740000017826 / score: 7.178571481099995
# step: 58627 / episode: 139 / progress: Training / epsilon: 0.9327480000017994 / score: 16.714285839899976
# step: 58761 / episode: 140 / progress: Training / epsilon: 0.9324800000018065 / score: 5.050000111099997
# step: 58885 / episode: 141 / progress: Training / epsilon: 0.9322320000018132 / score: 5.542857091099996
# step: 59013 / episode: 142 / progress: Training / epsilon: 0.93197600000182 / score: 5.3500000541999935
# step: 59201 / episode: 143 / progress: Training / epsilon: 0.9316000000018301 / score: 10.100000038099981
# step: 59433 / episode: 144 / progress: Training / epsilon: 0.9311360000018425 / score: 12.357142967899994
# step: 59599 / episode: 145 / progress: Training / epsilon: 0.9308040000018514 / score: 6.421428684499995
# step: 59952 / episode: 146 / progress: Training / epsilon: 0.9300980000018703 / score: 18.1714286257
# step: 60102 / episode: 147 / progress: Training / epsilon: 0.9297980000018783 / score: 12.057142977499991
# step: 60701 / episode: 148 / progress: Training / epsilon: 0.9286000000019103 / score: 29.685714585499966
# step: 60876 / episode: 149 / progress: Training / epsilon: 0.9282500000019197 / score: 7.785714386300008
# step: 61040 / episode: 150 / progress: Training / epsilon: 0.9279220000019285 / score: 6.671428684999995
# step: 61192 / episode: 151 / progress: Training / epsilon: 0.9276180000019366 / score: 6.592857227499993
# step: 61316 / episode: 152 / progress: Training / epsilon: 0.9273700000019433 / score: 5.371428663599998
# step: 61825 / episode: 153 / progress: Training / epsilon: 0.9263520000019705 / score: 31.021428841200063
# step: 62019 / episode: 154 / progress: Training / epsilon: 0.9259640000019809 / score: 9.728571513299983
# step: 62148 / episode: 155 / progress: Training / epsilon: 0.9257060000019878 / score: 3.800000050399995
# step: 62688 / episode: 156 / progress: Training / epsilon: 0.9246260000020167 / score: 33.30000024219992
# step: 62896 / episode: 157 / progress: Training / epsilon: 0.9242100000020278 / score: 11.050000153100001
# step: 63582 / episode: 158 / progress: Training / epsilon: 0.9228380000020645 / score: 46.792857251699886
# step: 63794 / episode: 159 / progress: Training / epsilon: 0.9224140000020759 / score: 6.8071429719999905
# step: 63913 / episode: 160 / progress: Training / epsilon: 0.9221760000020822 / score: 3.1857143766999982
# step: 64342 / episode: 161 / progress: Training / epsilon: 0.9213180000021052 / score: 24.078571722100023
# step: 64539 / episode: 162 / progress: Training / epsilon: 0.9209240000021157 / score: 8.557143007099985
# step: 64851 / episode: 163 / progress: Training / epsilon: 0.9203000000021324 / score: 20.514285648799945
# step: 65052 / episode: 164 / progress: Training / epsilon: 0.9198980000021432 / score: 10.46428586429999
# step: 65248 / episode: 165 / progress: Training / epsilon: 0.9195060000021537 / score: 7.428571474699989
# step: 65372 / episode: 166 / progress: Training / epsilon: 0.9192580000021603 / score: 5.164285814599997
# step: 65512 / episode: 167 / progress: Training / epsilon: 0.9189780000021678 / score: 8.707142967600005
# step: 65878 / episode: 168 / progress: Training / epsilon: 0.9182460000021874 / score: 19.357142970599963
# step: 66107 / episode: 169 / progress: Training / epsilon: 0.9177880000021996 / score: 12.05714300879999
# step: 66277 / episode: 170 / progress: Training / epsilon: 0.9174480000022087 / score: 9.221428664099994
# step: 66507 / episode: 171 / progress: Training / epsilon: 0.916988000002221 / score: 10.45000006399999
# step: 66656 / episode: 172 / progress: Training / epsilon: 0.916690000002229 / score: 7.2857143729999905
# step: 66932 / episode: 173 / progress: Training / epsilon: 0.9161380000022438 / score: 16.300000072799985
# step: 67090 / episode: 174 / progress: Training / epsilon: 0.9158220000022522 / score: 7.592857260499995
# step: 67208 / episode: 175 / progress: Training / epsilon: 0.9155860000022585 / score: 4.492857193099999
# step: 67736 / episode: 176 / progress: Training / epsilon: 0.9145300000022868 / score: 36.31428601479994
# step: 68129 / episode: 177 / progress: Training / epsilon: 0.9137440000023078 / score: 22.514285991100007
# step: 68355 / episode: 178 / progress: Training / epsilon: 0.9132920000023199 / score: 11.800000156700005
# step: 68472 / episode: 179 / progress: Training / epsilon: 0.9130580000023262 / score: 4.092857223699996
# step: 68632 / episode: 180 / progress: Training / epsilon: 0.9127380000023347 / score: 7.271428578799995
# step: 68992 / episode: 181 / progress: Training / epsilon: 0.912018000002354 / score: 19.507143026699975
# step: 69120 / episode: 182 / progress: Training / epsilon: 0.9117620000023609 / score: 7.564285788099998
# step: 69337 / episode: 183 / progress: Training / epsilon: 0.9113280000023725 / score: 11.285714371099994
# step: 69475 / episode: 184 / progress: Training / epsilon: 0.9110520000023798 / score: 5.814285804799993
# step: 69818 / episode: 185 / progress: Training / epsilon: 0.9103660000023982 / score: 18.57142880320003
# step: 69988 / episode: 186 / progress: Training / epsilon: 0.9100260000024073 / score: 8.592857262899996
# step: 70211 / episode: 187 / progress: Training / epsilon: 0.9095800000024192 / score: 9.878571547799993
# step: 70544 / episode: 188 / progress: Training / epsilon: 0.908914000002437 / score: 15.550000045799948
# step: 70662 / episode: 189 / progress: Training / epsilon: 0.9086780000024434 / score: 5.435714382399995
# step: 70826 / episode: 190 / progress: Training / epsilon: 0.9083500000024521 / score: 7.9428572679000045
# step: 70994 / episode: 191 / progress: Training / epsilon: 0.9080140000024611 / score: 8.778571502099991
# step: 71174 / episode: 192 / progress: Training / epsilon: 0.9076540000024708 / score: 11.14285720609999
# step: 71339 / episode: 193 / progress: Training / epsilon: 0.9073240000024796 / score: 11.335714415999998
# step: 71563 / episode: 194 / progress: Training / epsilon: 0.9068760000024916 / score: 11.564285814399994
# step: 71715 / episode: 195 / progress: Training / epsilon: 0.9065720000024997 / score: 6.564285830699996
# step: 72086 / episode: 196 / progress: Training / epsilon: 0.9058300000025196 / score: 21.37142861619991
# step: 72232 / episode: 197 / progress: Training / epsilon: 0.9055380000025274 / score: 4.885714379199999
# step: 72353 / episode: 198 / progress: Training / epsilon: 0.9052960000025339 / score: 6.185714385699999
# step: 72573 / episode: 199 / progress: Training / epsilon: 0.9048560000025456 / score: 10.492857258999983
# step: 72974 / episode: 200 / progress: Training / epsilon: 0.9040540000025671 / score: 23.357143066900008
# step: 73341 / episode: 201 / progress: Training / epsilon: 0.9033200000025867 / score: 26.80000014319991
# step: 73475 / episode: 202 / progress: Training / epsilon: 0.9030520000025939 / score: 6.778571516700001
# step: 73634 / episode: 203 / progress: Training / epsilon: 0.9027340000026024 / score: 8.685714371300001
# step: 73813 / episode: 204 / progress: Training / epsilon: 0.902376000002612 / score: 9.042857238599984
# step: 73976 / episode: 205 / progress: Training / epsilon: 0.9020500000026207 / score: 8.728571559799997
# step: 74187 / episode: 206 / progress: Training / epsilon: 0.901628000002632 / score: 10.721428726599989
# step: 74379 / episode: 207 / progress: Training / epsilon: 0.9012440000026423 / score: 10.050000110600013
# step: 74792 / episode: 208 / progress: Training / epsilon: 0.9004180000026644 / score: 24.142857263699945
# step: 75003 / episode: 209 / progress: Training / epsilon: 0.8999960000026757 / score: 13.2357144588
# step: 75234 / episode: 210 / progress: Training / epsilon: 0.899534000002688 / score: 12.4285714963
# step: 75436 / episode: 211 / progress: Training / epsilon: 0.8991300000026988 / score: 8.092857238299997
# step: 75792 / episode: 212 / progress: Training / epsilon: 0.8984180000027179 / score: 20.11428596460006
# step: 76013 / episode: 213 / progress: Training / epsilon: 0.8979760000027297 / score: 11.80714298
# step: 76151 / episode: 214 / progress: Training / epsilon: 0.8977000000027371 / score: 6.200000082199999
# step: 76376 / episode: 215 / progress: Training / epsilon: 0.8972500000027491 / score: 11.271428703599994
# step: 76529 / episode: 216 / progress: Training / epsilon: 0.8969440000027573 / score: 7.064285807199996
# step: 76870 / episode: 217 / progress: Training / epsilon: 0.8962620000027756 / score: 20.75000004729999
# step: 77197 / episode: 218 / progress: Training / epsilon: 0.8956080000027931 / score: 20.071428685599955
# step: 77379 / episode: 219 / progress: Training / epsilon: 0.8952440000028028 / score: 8.800000111600001
# step: 77715 / episode: 220 / progress: Training / epsilon: 0.8945720000028208 / score: 25.171428690200056
# step: 77839 / episode: 221 / progress: Training / epsilon: 0.8943240000028274 / score: 6.564285822899995
# step: 78031 / episode: 222 / progress: Training / epsilon: 0.8939400000028377 / score: 7.800000077499998
# step: 78171 / episode: 223 / progress: Training / epsilon: 0.8936600000028452 / score: 6.321428680899997
# step: 78389 / episode: 224 / progress: Training / epsilon: 0.8932240000028568 / score: 13.528571583600003
# step: 78525 / episode: 225 / progress: Training / epsilon: 0.8929520000028641 / score: 6.992857238400003
# step: 78685 / episode: 226 / progress: Training / epsilon: 0.8926320000028727 / score: 8.342857254499995
# step: 78871 / episode: 227 / progress: Training / epsilon: 0.8922600000028826 / score: 9.335714384599996
# step: 79034 / episode: 228 / progress: Training / epsilon: 0.8919340000028914 / score: 7.464285811599984
# step: 79471 / episode: 229 / progress: Training / epsilon: 0.8910600000029147 / score: 27.550000097899893
# step: 79670 / episode: 230 / progress: Training / epsilon: 0.8906620000029254 / score: 11.028571565099993
# step: 79970 / episode: 231 / progress: Training / epsilon: 0.8900620000029414 / score: 15.57857165279998
# step: 80197 / episode: 232 / progress: Training / epsilon: 0.8896080000029536 / score: 10.50000011269999
# step: 80327 / episode: 233 / progress: Training / epsilon: 0.8893480000029605 / score: 6.9285715167
# step: 80550 / episode: 234 / progress: Training / epsilon: 0.8889020000029725 / score: 11.242857312200002
# step: 80919 / episode: 235 / progress: Training / epsilon: 0.8881640000029922 / score: 21.03571448569996
# step: 81303 / episode: 236 / progress: Training / epsilon: 0.8873960000030128 / score: 22.80714301320003
# step: 81511 / episode: 237 / progress: Training / epsilon: 0.8869800000030239 / score: 11.614285787099982
# step: 81728 / episode: 238 / progress: Training / epsilon: 0.8865460000030355 / score: 10.828571558099977
# step: 81864 / episode: 239 / progress: Training / epsilon: 0.8862740000030428 / score: 5.9571429647
# step: 81995 / episode: 240 / progress: Training / epsilon: 0.8860120000030498 / score: 7.985714298199996
# step: 82166 / episode: 241 / progress: Training / epsilon: 0.885670000003059 / score: 8.457142935700004
# step: 82370 / episode: 242 / progress: Training / epsilon: 0.8852620000030699 / score: 11.207143010100003
# step: 82545 / episode: 243 / progress: Training / epsilon: 0.8849120000030792 / score: 9.664285846599999
# step: 82721 / episode: 244 / progress: Training / epsilon: 0.8845600000030887 / score: 7.435714381899988
# step: 82916 / episode: 245 / progress: Training / epsilon: 0.8841700000030991 / score: 10.864285821000006
# step: 83043 / episode: 246 / progress: Training / epsilon: 0.8839160000031059 / score: 6.200000105299999
# step: 83174 / episode: 247 / progress: Training / epsilon: 0.8836540000031129 / score: 7.828571542000001
# step: 83355 / episode: 248 / progress: Training / epsilon: 0.8832920000031226 / score: 8.350000092399998
# step: 83486 / episode: 249 / progress: Training / epsilon: 0.8830300000031296 / score: 6.900000107500002
# step: 83625 / episode: 250 / progress: Training / epsilon: 0.882752000003137 / score: 5.464285769599992
# step: 83829 / episode: 251 / progress: Training / epsilon: 0.8823440000031479 / score: 10.92857155589999
# step: 84138 / episode: 252 / progress: Training / epsilon: 0.8817260000031645 / score: 19.28571451590005
# step: 84616 / episode: 253 / progress: Training / epsilon: 0.8807700000031901 / score: 26.79285744490003
# step: 85225 / episode: 254 / progress: Training / epsilon: 0.8795520000032226 / score: 42.571428862799735
# step: 85454 / episode: 255 / progress: Training / epsilon: 0.8790940000032349 / score: 10.107142944699982
# step: 85667 / episode: 256 / progress: Training / epsilon: 0.8786680000032463 / score: 9.921428672499987
# step: 85892 / episode: 257 / progress: Training / epsilon: 0.8782180000032583 / score: 10.364285779699994
# step: 86065 / episode: 258 / progress: Training / epsilon: 0.8778720000032676 / score: 7.457142888899989
# step: 86289 / episode: 259 / progress: Training / epsilon: 0.8774240000032796 / score: 13.15000015490001
# step: 86644 / episode: 260 / progress: Training / epsilon: 0.8767140000032986 / score: 22.250000150599988
# step: 86856 / episode: 261 / progress: Training / epsilon: 0.8762900000033099 / score: 12.307142969000003
# step: 87137 / episode: 262 / progress: Training / epsilon: 0.875728000003325 / score: 14.214285840799981
# step: 87259 / episode: 263 / progress: Training / epsilon: 0.8754840000033315 / score: 5.200000093399999
# step: 87442 / episode: 264 / progress: Training / epsilon: 0.8751180000033413 / score: 9.778571501699991
# step: 87672 / episode: 265 / progress: Training / epsilon: 0.8746580000033536 / score: 10.7214287469
# step: 87794 / episode: 266 / progress: Training / epsilon: 0.8744140000033601 / score: 6.764285803399995
# step: 88210 / episode: 267 / progress: Training / epsilon: 0.8735820000033824 / score: 26.65000028340001
# step: 88403 / episode: 268 / progress: Training / epsilon: 0.8731960000033927 / score: 10.7357144378
# step: 88545 / episode: 269 / progress: Training / epsilon: 0.8729120000034003 / score: 8.0000001013
# step: 88719 / episode: 270 / progress: Training / epsilon: 0.8725640000034096 / score: 10.392857151799987
# step: 88910 / episode: 271 / progress: Training / epsilon: 0.8721820000034198 / score: 8.771428692299986
# step: 89033 / episode: 272 / progress: Training / epsilon: 0.8719360000034264 / score: 5.107142927999996
# step: 89419 / episode: 273 / progress: Training / epsilon: 0.8711640000034471 / score: 23.14285729009998
# step: 89609 / episode: 274 / progress: Training / epsilon: 0.8707840000034572 / score: 8.107142984399994
# step: 89832 / episode: 275 / progress: Training / epsilon: 0.8703380000034692 / score: 11.07142869999999
# step: 90051 / episode: 276 / progress: Training / epsilon: 0.8699000000034809 / score: 12.59285731299999
# step: 90205 / episode: 277 / progress: Training / epsilon: 0.8695920000034891 / score: 8.535714404299997
# step: 90594 / episode: 278 / progress: Training / epsilon: 0.86881400000351 / score: 27.30000015889995
# step: 90784 / episode: 279 / progress: Training / epsilon: 0.8684340000035201 / score: 9.992857239799992
# step: 90932 / episode: 280 / progress: Training / epsilon: 0.868138000003528 / score: 7.742857260699994
# step: 91130 / episode: 281 / progress: Training / epsilon: 0.8677420000035386 / score: 11.90714298190001
# step: 91308 / episode: 282 / progress: Training / epsilon: 0.8673860000035482 / score: 5.807142942299997
# step: 91626 / episode: 283 / progress: Training / epsilon: 0.8667500000035652 / score: 17.878571599800026
# step: 91978 / episode: 284 / progress: Training / epsilon: 0.866046000003584 / score: 21.285714365699942
# step: 92108 / episode: 285 / progress: Training / epsilon: 0.865786000003591 / score: 5.985714369099988
# step: 92254 / episode: 286 / progress: Training / epsilon: 0.8654940000035988 / score: 5.0785714522
# step: 92404 / episode: 287 / progress: Training / epsilon: 0.8651940000036068 / score: 8.14285722849999
# step: 92540 / episode: 288 / progress: Training / epsilon: 0.8649220000036141 / score: 6.264285718700004
# step: 92658 / episode: 289 / progress: Training / epsilon: 0.8646860000036204 / score: 6.100000101500003
# step: 92837 / episode: 290 / progress: Training / epsilon: 0.86432800000363 / score: 6.9714286571999935
# step: 93818 / episode: 291 / progress: Training / epsilon: 0.8623660000036825 / score: 73.97857208959944
# step: 94016 / episode: 292 / progress: Training / epsilon: 0.8619700000036931 / score: 9.135714435399992
# step: 94196 / episode: 293 / progress: Training / epsilon: 0.8616100000037027 / score: 9.650000087199993
# step: 94578 / episode: 294 / progress: Training / epsilon: 0.8608460000037231 / score: 25.357143131100056
# step: 94779 / episode: 295 / progress: Training / epsilon: 0.8604440000037339 / score: 10.742857214199978
# step: 95225 / episode: 296 / progress: Training / epsilon: 0.8595520000037578 / score: 27.814286004799975
# step: 95372 / episode: 297 / progress: Training / epsilon: 0.8592580000037656 / score: 8.078571523599997
# step: 95519 / episode: 298 / progress: Training / epsilon: 0.8589640000037735 / score: 8.350000114399997
# step: 95891 / episode: 299 / progress: Training / epsilon: 0.8582200000037934 / score: 22.900000277300073
# step: 96170 / episode: 300 / progress: Training / epsilon: 0.8576620000038083 / score: 15.350000203300006
# step: 96518 / episode: 301 / progress: Training / epsilon: 0.8569660000038269 / score: 20.135714251199943
# step: 96683 / episode: 302 / progress: Training / epsilon: 0.8566360000038358 / score: 7.257142912899992
# step: 96842 / episode: 303 / progress: Training / epsilon: 0.8563180000038443 / score: 8.478571546899996
# step: 97060 / episode: 304 / progress: Training / epsilon: 0.855882000003856 / score: 10.8428572872
# step: 97236 / episode: 305 / progress: Training / epsilon: 0.8555300000038654 / score: 10.114285839699994
# step: 97431 / episode: 306 / progress: Training / epsilon: 0.8551400000038758 / score: 10.621428702899998
# step: 97657 / episode: 307 / progress: Training / epsilon: 0.8546880000038879 / score: 11.700000103399983
# step: 98017 / episode: 308 / progress: Training / epsilon: 0.8539680000039072 / score: 22.985714557700057
# step: 98394 / episode: 309 / progress: Training / epsilon: 0.8532140000039273 / score: 26.264285967100065
# step: 98525 / episode: 310 / progress: Training / epsilon: 0.8529520000039343 / score: 6.7785714165
# step: 98813 / episode: 311 / progress: Training / epsilon: 0.8523760000039498 / score: 20.521428584399935
# step: 98991 / episode: 312 / progress: Training / epsilon: 0.8520200000039593 / score: 13.571428680699993
# step: 99137 / episode: 313 / progress: Training / epsilon: 0.8517280000039671 / score: 7.650000038899991
# step: 99412 / episode: 314 / progress: Training / epsilon: 0.8511780000039818 / score: 16.62142877639999
# step: 99702 / episode: 315 / progress: Training / epsilon: 0.8505980000039973 / score: 16.32142856729999
# step: 100485 / episode: 316 / progress: Training / epsilon: 0.8490320000040392 / score: 50.60714303619995
# step: 100874 / episode: 317 / progress: Training / epsilon: 0.84825400000406 / score: 26.61428587890007
# step: 101050 / episode: 318 / progress: Training / epsilon: 0.8479020000040695 / score: 7.364285813299995
# step: 101621 / episode: 319 / progress: Training / epsilon: 0.8467600000041 / score: 34.2857145489
# step: 101746 / episode: 320 / progress: Training / epsilon: 0.8465100000041067 / score: 3.400000092199998
# step: 101955 / episode: 321 / progress: Training / epsilon: 0.8460920000041179 / score: 9.87142863259998
# step: 102126 / episode: 322 / progress: Training / epsilon: 0.845750000004127 / score: 11.5642858463
# step: 102313 / episode: 323 / progress: Training / epsilon: 0.845376000004137 / score: 9.357142843299991
# step: 102496 / episode: 324 / progress: Training / epsilon: 0.8450100000041468 / score: 10.428571564299999
# step: 102622 / episode: 325 / progress: Training / epsilon: 0.8447580000041536 / score: 5.3500001028999975
# step: 102946 / episode: 326 / progress: Training / epsilon: 0.8441100000041709 / score: 21.892857231299946
# step: 103135 / episode: 327 / progress: Training / epsilon: 0.843732000004181 / score: 9.264285785499991
# step: 103839 / episode: 328 / progress: Training / epsilon: 0.8423240000042187 / score: 45.978571686699766
# step: 104003 / episode: 329 / progress: Training / epsilon: 0.8419960000042275 / score: 8.80714292139999
# step: 104211 / episode: 330 / progress: Training / epsilon: 0.8415800000042386 / score: 10.414285762799995
# step: 104560 / episode: 331 / progress: Training / epsilon: 0.8408820000042573 / score: 22.442857415900043
# step: 104709 / episode: 332 / progress: Training / epsilon: 0.8405840000042653 / score: 7.485714319399996
# step: 105073 / episode: 333 / progress: Training / epsilon: 0.8398560000042847 / score: 21.657142968899937
# step: 105276 / episode: 334 / progress: Training / epsilon: 0.8394500000042956 / score: 11.878571577599995
# step: 105429 / episode: 335 / progress: Training / epsilon: 0.8391440000043038 / score: 7.578571496199993
# step: 105726 / episode: 336 / progress: Training / epsilon: 0.8385500000043197 / score: 16.707143056700012
# step: 106098 / episode: 337 / progress: Training / epsilon: 0.8378060000043396 / score: 21.507143065300003
# step: 106236 / episode: 338 / progress: Training / epsilon: 0.837530000004347 / score: 8.328571538600002
# step: 106397 / episode: 339 / progress: Training / epsilon: 0.8372080000043556 / score: 7.950000086599999
# step: 106942 / episode: 340 / progress: Training / epsilon: 0.8361180000043847 / score: 35.81428606619989
# step: 107169 / episode: 341 / progress: Training / epsilon: 0.8356640000043969 / score: 11.807142863399982
# step: 107382 / episode: 342 / progress: Training / epsilon: 0.8352380000044083 / score: 9.992857239899998
# step: 107707 / episode: 343 / progress: Training / epsilon: 0.8345880000044257 / score: 18.200000160699968
# step: 108058 / episode: 344 / progress: Training / epsilon: 0.8338860000044445 / score: 20.635714450800037
# step: 108194 / episode: 345 / progress: Training / epsilon: 0.8336140000044517 / score: 6.492857243199989
# step: 108362 / episode: 346 / progress: Training / epsilon: 0.8332780000044607 / score: 10.32857148369999
# step: 108761 / episode: 347 / progress: Training / epsilon: 0.8324800000044821 / score: 25.47857162049999
# step: 109303 / episode: 348 / progress: Training / epsilon: 0.8313960000045111 / score: 38.221428897299994
# step: 109499 / episode: 349 / progress: Training / epsilon: 0.8310040000045216 / score: 8.785714362699986
# step: 109786 / episode: 350 / progress: Training / epsilon: 0.8304300000045369 / score: 19.035714502400033
# step: 109952 / episode: 351 / progress: Training / epsilon: 0.8300980000045458 / score: 8.171428674699996
# step: 110675 / episode: 352 / progress: Training / epsilon: 0.8286520000045845 / score: 48.314285971099906
# step: 111048 / episode: 353 / progress: Training / epsilon: 0.8279060000046045 / score: 21.671428584199933
# step: 111238 / episode: 354 / progress: Training / epsilon: 0.8275260000046146 / score: 9.521428682599995
# step: 111452 / episode: 355 / progress: Training / epsilon: 0.8270980000046261 / score: 12.557143027700015
# step: 111885 / episode: 356 / progress: Training / epsilon: 0.8262320000046492 / score: 34.39285715529988
# step: 112212 / episode: 357 / progress: Training / epsilon: 0.8255780000046667 / score: 17.257143058399986
# step: 112371 / episode: 358 / progress: Training / epsilon: 0.8252600000046753 / score: 7.821428685200001
# step: 112939 / episode: 359 / progress: Training / epsilon: 0.8241240000047056 / score: 40.27142868249987
# step: 113095 / episode: 360 / progress: Training / epsilon: 0.823812000004714 / score: 9.250000131899998
# step: 113484 / episode: 361 / progress: Training / epsilon: 0.8230340000047348 / score: 22.585714583500035
# step: 113703 / episode: 362 / progress: Training / epsilon: 0.8225960000047465 / score: 10.207143010699994
# step: 113862 / episode: 363 / progress: Training / epsilon: 0.822278000004755 / score: 7.407142893399994
# step: 114176 / episode: 364 / progress: Training / epsilon: 0.8216500000047718 / score: 20.142857146099953
# step: 114468 / episode: 365 / progress: Training / epsilon: 0.8210660000047875 / score: 18.34285737030004
# step: 114826 / episode: 366 / progress: Training / epsilon: 0.8203500000048066 / score: 20.950000070100025
# step: 114987 / episode: 367 / progress: Training / epsilon: 0.8200280000048152 / score: 10.549999987999993
# step: 115328 / episode: 368 / progress: Training / epsilon: 0.8193460000048335 / score: 21.000000091999922
# step: 115675 / episode: 369 / progress: Training / epsilon: 0.818652000004852 / score: 18.83571442649999
# ...
# step: 453987 / episode: 1122 / progress: Training / epsilon: 0.14202800001301974 / score: 30.900000142500147
# step: 455947 / episode: 1123 / progress: Training / epsilon: 0.13810800001301582 / score: 177.12857121550195
# step: 456262 / episode: 1124 / progress: Training / epsilon: 0.1374780000130152 / score: 26.34999979819989
# step: 456829 / episode: 1125 / progress: Training / epsilon: 0.13634400001301406 / score: 47.814285674099715
# step: 458036 / episode: 1126 / progress: Training / epsilon: 0.13393000001301164 / score: 112.72857115890046
# step: 459688 / episode: 1127 / progress: Training / epsilon: 0.13062600001300834 / score: 146.75714201820395
# step: 462600 / episode: 1128 / progress: Training / epsilon: 0.12480200001300251 / score: 258.0214287234022
# step: 465086 / episode: 1129 / progress: Training / epsilon: 0.11983000001299754 / score: 215.0857129058056
# step: 465584 / episode: 1130 / progress: Training / epsilon: 0.11883400001299654 / score: 41.671428566299745
# step: 466686 / episode: 1131 / progress: Training / epsilon: 0.11663000001299434 / score: 97.6571425722014
# step: 467158 / episode: 1132 / progress: Training / epsilon: 0.1156860000129934 / score: 42.27142873250021
# step: 467281 / episode: 1133 / progress: Training / epsilon: 0.11544000001299315 / score: 9.364285749999993
# step: 468586 / episode: 1134 / progress: Training / epsilon: 0.11283000001299054 / score: 117.02857067350004
# step: 469852 / episode: 1135 / progress: Training / epsilon: 0.110298000012988 / score: 118.60714243770262
# step: 470380 / episode: 1136 / progress: Training / epsilon: 0.10924200001298695 / score: 45.71428554599988
# step: 473499 / episode: 1137 / progress: Training / epsilon: 0.10300400001298071 / score: 276.8142839649021
# step: 475315 / episode: 1138 / progress: Training / epsilon: 0.0999980000129777 / score: 170.46428537510045
# step: 476631 / episode: 1139 / progress: Training / epsilon: 0.0999980000129777 / score: 108.28571389769986
# step: 478701 / episode: 1140 / progress: Training / epsilon: 0.0999980000129777 / score: 185.04999889140458
# step: 479213 / episode: 1141 / progress: Training / epsilon: 0.0999980000129777 / score: 41.46428596919999
# step: 479488 / episode: 1142 / progress: Training / epsilon: 0.0999980000129777 / score: 21.75714304170005
# step: 481327 / episode: 1143 / progress: Training / epsilon: 0.0999980000129777 / score: 172.23571378940406
# step: 482532 / episode: 1144 / progress: Training / epsilon: 0.0999980000129777 / score: 110.90714252780066
# step: 483029 / episode: 1145 / progress: Training / epsilon: 0.0999980000129777 / score: 39.57142848499979
# step: 485650 / episode: 1146 / progress: Training / epsilon: 0.0999980000129777 / score: 238.5142845517036
# step: 485811 / episode: 1147 / progress: Training / epsilon: 0.0999980000129777 / score: 12.642857192899983
# step: 486167 / episode: 1148 / progress: Training / epsilon: 0.0999980000129777 / score: 33.65714304400013
# step: 486301 / episode: 1149 / progress: Training / epsilon: 0.0999980000129777 / score: 10.214285764899984
# step: 486820 / episode: 1150 / progress: Training / epsilon: 0.0999980000129777 / score: 43.335714372199995
# step: 487112 / episode: 1151 / progress: Training / epsilon: 0.0999980000129777 / score: 24.892857269800082
# step: 488487 / episode: 1152 / progress: Training / epsilon: 0.0999980000129777 / score: 125.79285679409999
# step: 489591 / episode: 1153 / progress: Training / epsilon: 0.0999980000129777 / score: 96.46428607790146
# step: 490241 / episode: 1154 / progress: Training / epsilon: 0.0999980000129777 / score: 53.349999976899824
# step: 490384 / episode: 1155 / progress: Training / epsilon: 0.0999980000129777 / score: 10.67857149129999
# step: 490664 / episode: 1156 / progress: Training / epsilon: 0.0999980000129777 / score: 22.742857269400073
# step: 490837 / episode: 1157 / progress: Training / epsilon: 0.0999980000129777 / score: 13.571428619699981
# step: 491859 / episode: 1158 / progress: Training / epsilon: 0.0999980000129777 / score: 93.62857126739819
# step: 492354 / episode: 1159 / progress: Training / epsilon: 0.0999980000129777 / score: 43.928571124499776
# step: 493671 / episode: 1160 / progress: Training / epsilon: 0.0999980000129777 / score: 118.95714306570129
# step: 494110 / episode: 1161 / progress: Training / epsilon: 0.0999980000129777 / score: 36.99285728729981
# step: 494422 / episode: 1162 / progress: Training / epsilon: 0.0999980000129777 / score: 26.850000108400103
# step: 495220 / episode: 1163 / progress: Training / epsilon: 0.0999980000129777 / score: 66.19999989589971
# step: 495604 / episode: 1164 / progress: Training / epsilon: 0.0999980000129777 / score: 33.53571426699989
# step: 496188 / episode: 1165 / progress: Training / epsilon: 0.0999980000129777 / score: 51.35714283059966
# step: 496971 / episode: 1166 / progress: Training / epsilon: 0.0999980000129777 / score: 74.43571473119924
# step: 497178 / episode: 1167 / progress: Training / epsilon: 0.0999980000129777 / score: 22.364285811000002
# step: 498341 / episode: 1168 / progress: Training / epsilon: 0.0999980000129777 / score: 100.32857120180037
# step: 499556 / episode: 1169 / progress: Training / epsilon: 0.0999980000129777 / score: 107.04285763719798
# step: 500405 / episode: 1170 / progress: Training / epsilon: 0.0999980000129777 / score: 68.4571428857995
# step: 500929 / episode: 1171 / progress: Training / epsilon: 0.0999980000129777 / score: 45.342856865899996
# step: 501402 / episode: 1172 / progress: Training / epsilon: 0.0999980000129777 / score: 40.39285713989979
# step: 503417 / episode: 1173 / progress: Training / epsilon: 0.0999980000129777 / score: 184.357142567902
# step: 503847 / episode: 1174 / progress: Training / epsilon: 0.0999980000129777 / score: 36.26428568699985
# step: 503980 / episode: 1175 / progress: Training / epsilon: 0.0999980000129777 / score: 9.578571476199986
# step: 504139 / episode: 1176 / progress: Training / epsilon: 0.0999980000129777 / score: 12.221428619099985
# step: 505056 / episode: 1177 / progress: Training / epsilon: 0.0999980000129777 / score: 84.00000002190075
# step: 505369 / episode: 1178 / progress: Training / epsilon: 0.0999980000129777 / score: 25.121428754600085
# step: 507508 / episode: 1179 / progress: Training / epsilon: 0.0999980000129777 / score: 177.3357135172032
# step: 507857 / episode: 1180 / progress: Training / epsilon: 0.0999980000129777 / score: 27.121428675499907
# step: 508220 / episode: 1181 / progress: Training / epsilon: 0.0999980000129777 / score: 29.664286037099853
# step: 508586 / episode: 1182 / progress: Training / epsilon: 0.0999980000129777 / score: 26.828571700100117
# step: 510276 / episode: 1183 / progress: Training / epsilon: 0.0999980000129777 / score: 137.32142928780019
# step: 511042 / episode: 1184 / progress: Training / epsilon: 0.0999980000129777 / score: 63.79285744329964
# step: 513773 / episode: 1185 / progress: Training / epsilon: 0.0999980000129777 / score: 233.6285713221028
# step: 514595 / episode: 1186 / progress: Training / epsilon: 0.0999980000129777 / score: 68.55714287160019
# step: 515401 / episode: 1187 / progress: Training / epsilon: 0.0999980000129777 / score: 65.20714280879969
# step: 516462 / episode: 1188 / progress: Training / epsilon: 0.0999980000129777 / score: 90.72142867880058
# step: 516841 / episode: 1189 / progress: Training / epsilon: 0.0999980000129777 / score: 33.571428707500154
# step: 517304 / episode: 1190 / progress: Training / epsilon: 0.0999980000129777 / score: 37.53571372929984
# step: 518483 / episode: 1191 / progress: Training / epsilon: 0.0999980000129777 / score: 109.31428498330187
# step: 521593 / episode: 1192 / progress: Training / epsilon: 0.0999980000129777 / score: 301.2214282133111
# step: 522931 / episode: 1193 / progress: Training / epsilon: 0.0999980000129777 / score: 116.62857148080069
# step: 523107 / episode: 1194 / progress: Training / epsilon: 0.0999980000129777 / score: 14.535714339999974
# step: 523320 / episode: 1195 / progress: Training / epsilon: 0.0999980000129777 / score: 20.678571524599988
# step: 523435 / episode: 1196 / progress: Training / epsilon: 0.0999980000129777 / score: 7.828571466199998
# step: 523719 / episode: 1197 / progress: Training / epsilon: 0.0999980000129777 / score: 22.964285595799915
# step: 524098 / episode: 1198 / progress: Training / epsilon: 0.0999980000129777 / score: 31.471428727200113
# step: 524503 / episode: 1199 / progress: Training / epsilon: 0.0999980000129777 / score: 34.05714304350008
# step: 524780 / episode: 1200 / progress: Training / epsilon: 0.0999980000129777 / score: 30.17142855849994
# Model saved in file: saved_networks/2018-01-28_19_48_DuelingDQN/model.ckpt
# step: 526199 / episode: 1201 / progress: Testing / epsilon: 0 / score: 123.39285639080322
# step: 527333 / episode: 1202 / progress: Testing / epsilon: 0 / score: 107.83571435139777
# step: 530312 / episode: 1203 / progress: Testing / epsilon: 0 / score: 276.6999967278066
# step: 530731 / episode: 1204 / progress: Testing / epsilon: 0 / score: 39.04285723180016
# step: 531101 / episode: 1205 / progress: Testing / epsilon: 0 / score: 35.9000000838001
# step: 531329 / episode: 1206 / progress: Testing / epsilon: 0 / score: 19.450000029600016
# step: 532302 / episode: 1207 / progress: Testing / epsilon: 0 / score: 100.45000028549924
# step: 533004 / episode: 1208 / progress: Testing / epsilon: 0 / score: 82.5714290225
# step: 533806 / episode: 1209 / progress: Testing / epsilon: 0 / score: 73.65714179350083
# step: 534714 / episode: 1210 / progress: Testing / epsilon: 0 / score: 75.76428544420057
# step: 536200 / episode: 1211 / progress: Testing / epsilon: 0 / score: 129.87857153939893
# step: 537398 / episode: 1212 / progress: Testing / epsilon: 0 / score: 126.24999938479968
# step: 537845 / episode: 1213 / progress: Testing / epsilon: 0 / score: 38.79285664949989
# step: 537991 / episode: 1214 / progress: Testing / epsilon: 0 / score: 11.642857175899978
# step: 538809 / episode: 1215 / progress: Testing / epsilon: 0 / score: 72.62857198200008
# step: 539474 / episode: 1216 / progress: Testing / epsilon: 0 / score: 66.19285673219977
# step: 539826 / episode: 1217 / progress: Testing / epsilon: 0 / score: 28.47857114599989
# step: 540926 / episode: 1218 / progress: Testing / epsilon: 0 / score: 97.15000043699914
# step: 541070 / episode: 1219 / progress: Testing / epsilon: 0 / score: 12.08571429499997
# step: 541609 / episode: 1220 / progress: Testing / epsilon: 0 / score: 39.27857230729974
# step: 542450 / episode: 1221 / progress: Testing / epsilon: 0 / score: 73.49285731110045
# step: 546804 / episode: 1222 / progress: Testing / epsilon: 0 / score: 403.0142884824893
# step: 548326 / episode: 1223 / progress: Testing / epsilon: 0 / score: 147.10714277370127
# step: 548895 / episode: 1224 / progress: Testing / epsilon: 0 / score: 48.61428528600009
# step: 550849 / episode: 1225 / progress: Testing / epsilon: 0 / score: 176.7999978408
# step: 553894 / episode: 1226 / progress: Testing / epsilon: 0 / score: 271.45713961450656
# step: 555005 / episode: 1227 / progress: Testing / epsilon: 0 / score: 95.40000021099956
# step: 556959 / episode: 1228 / progress: Testing / epsilon: 0 / score: 176.36428241910627
# step: 557181 / episode: 1229 / progress: Testing / epsilon: 0 / score: 19.24285717300001
# step: 558252 / episode: 1230 / progress: Testing / epsilon: 0 / score: 93.0428555165017
# step: 558937 / episode: 1231 / progress: Testing / epsilon: 0 / score: 65.28571434250044
# step: 559978 / episode: 1232 / progress: Testing / epsilon: 0 / score: 88.87856976210057
# step: 561310 / episode: 1233 / progress: Testing / epsilon: 0 / score: 115.42857221820192
# step: 563264 / episode: 1234 / progress: Testing / epsilon: 0 / score: 185.67142761350567
# step: 563822 / episode: 1235 / progress: Testing / epsilon: 0 / score: 47.728571775899695
# step: 564615 / episode: 1236 / progress: Testing / epsilon: 0 / score: 69.2428574294994
# step: 564827 / episode: 1237 / progress: Testing / epsilon: 0 / score: 18.23571430230001
# step: 566520 / episode: 1238 / progress: Testing / epsilon: 0 / score: 151.1142829778036
# step: 568101 / episode: 1239 / progress: Testing / epsilon: 0 / score: 152.29285630760288
# step: 571338 / episode: 1240 / progress: Testing / epsilon: 0 / score: 305.3714294872963
# step: 571798 / episode: 1241 / progress: Testing / epsilon: 0 / score: 44.321428613000315
# step: 572206 / episode: 1242 / progress: Testing / epsilon: 0 / score: 37.114285759000175
# step: 572765 / episode: 1243 / progress: Testing / epsilon: 0 / score: 57.492857697599966
# step: 574105 / episode: 1244 / progress: Testing / epsilon: 0 / score: 127.44999925900157
# step: 577506 / episode: 1245 / progress: Testing / epsilon: 0 / score: 295.72857041520354
# step: 577885 / episode: 1246 / progress: Testing / epsilon: 0 / score: 35.30714287460021
# step: 578368 / episode: 1247 / progress: Testing / epsilon: 0 / score: 39.507143658999645
# step: 580436 / episode: 1248 / progress: Testing / epsilon: 0 / score: 198.2428558255045
# step: 580615 / episode: 1249 / progress: Testing / epsilon: 0 / score: 15.650000004999978
# step: 584113 / episode: 1250 / progress: Testing / epsilon: 0 / score: 314.6500015215091
# step: 586046 / episode: 1251 / progress: Testing / epsilon: 0 / score: 170.12857327250208
# step: 587988 / episode: 1252 / progress: Testing / epsilon: 0 / score: 171.91428257180493
# step: 588750 / episode: 1253 / progress: Testing / epsilon: 0 / score: 68.19999971629996
# step: 589809 / episode: 1254 / progress: Testing / epsilon: 0 / score: 89.57857210200073
# step: 592460 / episode: 1255 / progress: Testing / epsilon: 0 / score: 255.0142890817002
# step: 593134 / episode: 1256 / progress: Testing / epsilon: 0 / score: 58.77142840169965
# step: 594027 / episode: 1257 / progress: Testing / epsilon: 0 / score: 81.3642861080991
# step: 594284 / episode: 1258 / progress: Testing / epsilon: 0 / score: 27.24999992919989
# step: 594568 / episode: 1259 / progress: Testing / epsilon: 0 / score: 25.392857156700124
# step: 596059 / episode: 1260 / progress: Testing / epsilon: 0 / score: 128.14999937209706
# step: 596721 / episode: 1261 / progress: Testing / epsilon: 0 / score: 56.621428136499745
# step: 597728 / episode: 1262 / progress: Testing / epsilon: 0 / score: 96.53571355050185
# step: 598010 / episode: 1263 / progress: Testing / epsilon: 0 / score: 23.192857212400064
# step: 598402 / episode: 1264 / progress: Testing / epsilon: 0 / score: 33.592857582299814
# step: 600180 / episode: 1265 / progress: Testing / epsilon: 0 / score: 172.74285682400173
# step: 600721 / episode: 1266 / progress: Testing / epsilon: 0 / score: 47.70000004209972
# step: 602387 / episode: 1267 / progress: Testing / epsilon: 0 / score: 152.05714131169924
# step: 602553 / episode: 1268 / progress: Testing / epsilon: 0 / score: 13.521428604699972
# step: 603496 / episode: 1269 / progress: Testing / epsilon: 0 / score: 84.22857031330113
# step: 606207 / episode: 1270 / progress: Testing / epsilon: 0 / score: 248.7714291240029
# step: 606519 / episode: 1271 / progress: Testing / epsilon: 0 / score: 38.10000008130007
# step: 608940 / episode: 1272 / progress: Testing / epsilon: 0 / score: 226.3357123575024
# step: 610972 / episode: 1273 / progress: Testing / epsilon: 0 / score: 185.41428515339962
# step: 611964 / episode: 1274 / progress: Testing / epsilon: 0 / score: 96.03571480729956
# step: 613104 / episode: 1275 / progress: Testing / epsilon: 0 / score: 114.92856993420382
# step: 615629 / episode: 1276 / progress: Testing / epsilon: 0 / score: 224.97857239700204
# step: 616786 / episode: 1277 / progress: Testing / epsilon: 0 / score: 99.94999898680106
# step: 619981 / episode: 1278 / progress: Testing / epsilon: 0 / score: 299.04285859988966
# step: 621105 / episode: 1279 / progress: Testing / epsilon: 0 / score: 114.78571494109875
# step: 623384 / episode: 1280 / progress: Testing / epsilon: 0 / score: 207.02857263149983
# step: 623759 / episode: 1281 / progress: Testing / epsilon: 0 / score: 33.92142861480011
# step: 624912 / episode: 1282 / progress: Testing / epsilon: 0 / score: 115.2571435991995
# Finished!!
