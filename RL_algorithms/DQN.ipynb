# %% [markdown]
# # Unity ML Agents
# ## Environment Basics
# This notebook contains a walkthrough of the basic functions of the Python API for Unity ML Agents. For instructions on building a Unity environment, see [here](https://github.com/Unity-Technologies/ml-agents/wiki/Getting-Started-with-Balance-Ball).

# %% [markdown]
# ### 1. Load dependencies

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import cv2
import random
import datetime
import os
import time

from unityagents import UnityEnvironment

# %matplotlib inline

# %% [markdown]
# ### 2. Set environment parameters
#
# Be sure to set `env_name` to the name of the Unity environment file you want to launch.

# %%
env_name = "./ML_Agent_Pong/ML_Agent_Pong" # Name of the Unity environment binary to launch
train_mode = True # Whether to run the environment in training or inference mode

# %% [markdown]
# ### 3. Start the environment
# `UnityEnvironment` launches and begins communication with the environment when instantiated.
#
# Environments contain _brains_ which are responsible for deciding the actions of their associated _agents_. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
env = UnityEnvironment(file_name=env_name)

# Examine environment parameters
print(str(env))

# Set the default brain to work with
default_brain = env.brain_names[0]
brain = env.brains[default_brain]
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of brains: 1
#         Reset Parameters :
#
# Unity brain name: Brain
#         Number of observations (per agent): 1
#         State space type: discrete
#         State space size (per agent): 1
#         Action space type: discrete
#         Action space size (per agent): 3
#         Memory space size (per agent): 0
#         Action descriptions: s, a, d

# %% [markdown]
# ### 4. Examine the observation and state spaces
# We can reset the environment to be provided with an initial set of observations and states for all the agents within the environment. In ML-Agents, _states_ refer to a vector of variables corresponding to relevant aspects of the environment for an agent. Likewise, _observations_ refer to a set of relevant pixel-wise visuals for an agent.

# %%
# Reset the environment
env_info = env.reset(train_mode=train_mode)[default_brain]

# Examine the state space for the default brain
print("Agent state looks like: \n{}".format(env_info.vector_observations[0]))

# Examine the observation space for the default brain
Num_obs = len(env_info.visual_observations)

print("Agent observations look like:")
if Num_obs > 1:
    f, axarr = plt.subplots(1, Num_obs, figsize=(20,10))
    for i, observation in enumerate(env_info.visual_observations):
        if observation.shape[3] == 3:
            axarr[i].imshow(observation[0,:,:,:])
            axarr[i].axis('off')
        else:
            axarr[i].imshow(observation[0,:,:,0])
            axarr[i].axis('off')
else:
    f, axarr = plt.subplots(1, Num_obs)
    for i, observation in enumerate(env_info.visual_observations):
        if observation.shape[3] == 3:
            axarr.imshow(observation[0,:,:,:])
            axarr.axis('off')
        else:
            axarr.imshow(observation[0,:,:,0])
            axarr.axis('off')
# Out:
# Agent state looks like:
# [ 0.]
# Agent observations look like:

# %% [markdown]
# ### 5. Parameters

# %%
import random

Gamma = 0.99
Learning_rate = 0.00025

algorithm = 'DQN'
Num_action = brain.vector_action_space_size

Num_replay_memory = 50000
Num_start_training = 25000
Num_training = 500000
Num_update = 5000
Num_batch = 32
Num_test = 50000
Num_skipFrame = 4
Num_stackFrame = 4
Num_colorChannel = 1

Epsilon = 1.0
Final_epsilon = 0.1

Num_plot_episode = 20
Num_step_save = 50000

GPU_fraction = 0.3

img_size = 80

first_conv   = [8,8,Num_colorChannel * Num_stackFrame * Num_obs,32]
second_conv  = [4,4,32,64]
third_conv   = [3,3,64,64]
first_dense  = [10*10*64, 512]
second_dense = [first_dense[1], Num_action]

train_mode = True
env_info = env.reset(train_mode=train_mode)[default_brain]

score_list = []
check_show_progress = 0

load_path = 'saved_networks/2018-03-19_1_43_NoisyDDQN/model.ckpt'

# %% [markdown]
# ### Functions for Networks

# %%
# Initialize weights and bias
def weight_variable(shape):
    return tf.Variable(xavier_initializer(shape))

def bias_variable(shape):
	return tf.Variable(xavier_initializer(shape))

def mu_variable(shape):
    return tf.Variable(tf.random_uniform(shape, minval = -tf.sqrt(3/shape[0]), maxval = tf.sqrt(3/shape[0])))

def sigma_variable(shape):
	return tf.Variable(tf.constant(0.017, shape = shape))

# Xavier Weights initializer
def xavier_initializer(shape):
	dim_sum = np.sum(shape)
	if len(shape) == 1:
		dim_sum += 1
	bound = np.sqrt(2.0 / dim_sum)
	return tf.random_uniform(shape, minval=-bound, maxval=bound)

# Convolution and pooling
def conv2d(x,w, stride):
	return tf.nn.conv2d(x,w,strides=[1, stride, stride, 1], padding='SAME')

def max_pool_2x2(x):
	return tf.nn.max_pool(x, ksize=[1,2,2,1], strides=[1,2,2,1], padding='SAME')

def assign_network_to_target():
	# Get trainable variables
	trainable_variables = tf.trainable_variables()
	# network lstm variables
	trainable_variables_network = [var for var in trainable_variables if var.name.startswith('network')]

	# target lstm variables
	trainable_variables_target = [var for var in trainable_variables if var.name.startswith('target')]

	for i in range(len(trainable_variables_network)):
		sess.run(tf.assign(trainable_variables_target[i], trainable_variables_network[i]))

# Code for tensorboard
def setup_summary():
    episode_score   = tf.Variable(0.)

    tf.summary.scalar('Average_Score/' + str(Num_plot_episode) + 'episodes', episode_score)

    summary_vars = [episode_score]
    summary_placeholders = [tf.placeholder(tf.float32) for _ in range(len(summary_vars))]
    update_ops = [summary_vars[i].assign(summary_placeholders[i]) for i in range(len(summary_vars))]
    summary_op = tf.summary.merge_all()
    return summary_placeholders, update_ops, summary_op

# %% [markdown]
# ### Network

# %%
# Input
x_image = tf.placeholder(tf.float32, shape = [None, img_size, img_size, Num_colorChannel * Num_stackFrame * Num_obs])
x_normalize = (x_image - (255.0/2)) / (255.0/2)

with tf.variable_scope('network'):
	# Convolution variables
	w_conv1 = weight_variable(first_conv)
	b_conv1 = bias_variable([first_conv[3]])

	w_conv2 = weight_variable(second_conv)
	b_conv2 = bias_variable([second_conv[3]])

	w_conv3 = weight_variable(third_conv)
	b_conv3 = bias_variable([third_conv[3]])

	# Densely connect layer variables
	w_fc1 = weight_variable(first_dense)
	b_fc1 = bias_variable([first_dense[1]])

	w_fc2 = weight_variable(second_dense)
	b_fc2 = bias_variable([second_dense[1]])

# Network
h_conv1 = tf.nn.relu(conv2d(x_normalize, w_conv1, 4) + b_conv1)
h_conv2 = tf.nn.relu(conv2d(h_conv1, w_conv2, 2) + b_conv2)
h_conv3 = tf.nn.relu(conv2d(h_conv2, w_conv3, 1) + b_conv3)

h_pool3_flat = tf.reshape(h_conv3, [-1, first_dense[0]])
h_fc1 = tf.nn.relu(tf.matmul(h_pool3_flat, w_fc1)+b_fc1)

output = tf.matmul(h_fc1, w_fc2) + b_fc2

with tf.variable_scope('target'):
	# Convolution variables target
	w_conv1_target = weight_variable(first_conv)
	b_conv1_target = bias_variable([first_conv[3]])

	w_conv2_target = weight_variable(second_conv)
	b_conv2_target = bias_variable([second_conv[3]])

	w_conv3_target = weight_variable(third_conv)
	b_conv3_target = bias_variable([third_conv[3]])

	# Densely connect layer variables target
	w_fc1_target = weight_variable(first_dense)
	b_fc1_target = bias_variable([first_dense[1]])

	w_fc2_target = weight_variable(second_dense)
	b_fc2_target = bias_variable([second_dense[1]])

# Target Network
h_conv1_target = tf.nn.relu(conv2d(x_normalize, w_conv1_target, 4) + b_conv1_target)
h_conv2_target = tf.nn.relu(conv2d(h_conv1_target, w_conv2_target, 2) + b_conv2_target)
h_conv3_target = tf.nn.relu(conv2d(h_conv2_target, w_conv3_target, 1) + b_conv3_target)

h_pool3_flat_target = tf.reshape(h_conv3_target, [-1, first_dense[0]])
h_fc1_target = tf.nn.relu(tf.matmul(h_pool3_flat_target, w_fc1_target)+b_fc1_target)

output_target = tf.matmul(h_fc1_target, w_fc2_target) + b_fc2

# %% [markdown]
# ## Loss and Train

# %%
# Loss function and Train
action_target = tf.placeholder(tf.float32, shape = [None, Num_action])
y_target = tf.placeholder(tf.float32, shape = [None])

y_prediction = tf.reduce_sum(tf.multiply(output, action_target), reduction_indices = 1)
Loss = tf.reduce_mean(tf.square(y_prediction - y_target))
train_step = tf.train.AdamOptimizer(learning_rate = Learning_rate, epsilon = 1e-02).minimize(Loss)

# %% [markdown]
# ### Config

# %%
## Initialize variables
config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = GPU_fraction

sess = tf.InteractiveSession(config=config)

init = tf.global_variables_initializer()
sess.run(init)
# Out:
# Is there any saved data?(1=y/2=n): 2

# %% [markdown]
# ## Training or Inference?

# %%
# Load the file if the saved file exists
saver = tf.train.Saver()

# check_save = 1
check_save = input('Inference? / Training?(1=Inference/2=Training): ')

if check_save == '1':
    # Directly start inference
    Num_start_training = 0
    Num_training = 0
    
    # Restore variables from disk.
    saver.restore(sess, load_path)
    print("Model restored.")

# date - hour - minute of training time
date_time = str(datetime.date.today()) + '_' + str(datetime.datetime.now().hour) + '_' + str(datetime.datetime.now().minute)

# Make folder for save data
os.makedirs('saved_networks/' + date_time + '_' + algorithm)

# Summary for tensorboard
summary_placeholders, update_ops, summary_op = setup_summary()
summary_writer = tf.summary.FileWriter('saved_networks/' + date_time + '_' + algorithm, sess.graph)

# %% [markdown]
# ### Functions for Training

# %%
# Initialize_input
def input_initialization(env_info):
    observation_stack_obs = np.zeros([img_size, img_size, Num_colorChannel * Num_obs])
    
    for i in range(Num_obs):
        observation = 255 * env_info.visual_observations[i]
        observation = np.uint8(observation)
        observation = np.reshape(observation, (80, 80, 3))
        observation = cv2.resize(observation, (img_size, img_size))

        if Num_colorChannel == 1:
            observation = cv2.cvtColor(observation, cv2.COLOR_RGB2GRAY)
            observation = np.reshape(observation, (img_size, img_size))

        if Num_colorChannel == 3:
            observation_stack_obs[:,:, Num_colorChannel * i: Num_colorChannel * (i+1)] = observation
        else:
            observation_stack_obs[:,:, i] = observation

    observation_set = []

    for i in range(Num_skipFrame * Num_stackFrame):
        observation_set.append(observation_stack_obs)
    
    # Stack the frame according to the number of skipping and stacking frames using observation set
    observation_stack = np.zeros((img_size, img_size, Num_colorChannel * Num_stackFrame * Num_obs))
    for stack_frame in range(Num_stackFrame):
        observation_stack[:,:,Num_obs * stack_frame: Num_obs * (stack_frame+1)] = observation_set[-1 - (Num_skipFrame * stack_frame)]

    observation_stack = np.uint8(observation_stack)

    return observation_stack, observation_set

def resize_input(env_info, observation_set):
    # Stack observation according to the number of observations
    observation_stack_obs = np.zeros([img_size, img_size, Num_colorChannel * Num_obs])

    for i in range(Num_obs):
        observation = 255 * env_info.visual_observations[i]
        observation = np.uint8(observation)
        observation = np.reshape(observation, (80, 80, 3))
        observation = cv2.resize(observation, (img_size, img_size))
        
        if Num_colorChannel == 1:
            observation = cv2.cvtColor(observation, cv2.COLOR_RGB2GRAY)
            observation = np.reshape(observation, (img_size, img_size))

        if Num_colorChannel == 3:
            observation_stack_obs[:,:, Num_colorChannel * i: Num_colorChannel * (i+1)] = observation
        else:
            observation_stack_obs[:,:,i] = observation
    
    # Add observations to the observation_set
    observation_set.append(observation_stack_obs)
    
    # Stack the frame according to the number of skipping and stacking frames using observation set
    observation_stack = np.zeros((img_size, img_size, Num_colorChannel * Num_stackFrame * Num_obs))
    for stack_frame in range(Num_stackFrame):
        observation_stack[:,:,Num_obs * stack_frame: Num_obs * (stack_frame+1)] = observation_set[-1 - (Num_skipFrame * stack_frame)]

    del observation_set[0]

    observation_stack = np.uint8(observation_stack)
    
    return observation_stack, observation_set

# Get progress according to the 
def get_progress(step, Epsilon):
    if step <= Num_start_training:
        # Observation
        progress = 'Observing'
        train_mode = True
        Epsilon = 1

    elif step <= Num_start_training + Num_training:
        # Training
        progress = 'Training'
        train_mode = True
        
        # Decrease the epsilon value
        if Epsilon > Final_epsilon:
            Epsilon -= 1.0/Num_training
        
    elif step < Num_start_training + Num_training + Num_test:
        # Testing
        progress = 'Testing'
        train_mode = False
        Epsilon = 0

    else:
        # Finished
        progress = 'Finished'
        train_mode = False
        Epsilon = 0
        
    return progress, train_mode, Epsilon 

# Select action according to the progress of training
def select_action(progress, sess, observation_stack, Epsilon):
    if progress == "Observing":
        Q_value = 0
        action = np.zeros([Num_action])
        action[random.randint(0, Num_action - 1)] = 1.0
    elif progress == "Training":
        # if random value(0 - 1) is smaller than Epsilon, action is random. Otherwise, action is the one which has the largest Q value
        if random.random() < Epsilon:
            Q_value = 0
            action = np.zeros([Num_action])
            action[random.randint(0, Num_action - 1)] = 1
        else:
            Q_value = output.eval(feed_dict={x_image: [observation_stack]})
            action = np.zeros([Num_action])
            action[np.argmax(Q_value)] = 1
    else:
        Q_value = output.eval(feed_dict={x_image: [observation_stack]})
        action = np.zeros([Num_action])
        action[np.argmax(Q_value)] = 1
        
    return action, Q_value

def train(Replay_memory, sess, step):
    # Select minibatch
    minibatch =  random.sample(Replay_memory, Num_batch)

    # Save the each batch data
    observation_batch      = [batch[0] for batch in minibatch]
    action_batch           = [batch[1] for batch in minibatch]
    reward_batch           = [batch[2] for batch in minibatch]
    observation_next_batch = [batch[3] for batch in minibatch]
    terminal_batch 	       = [batch[4] for batch in minibatch]

    # Update target network according to the Num_update value
    if step % Num_update == 0:
        assign_network_to_target()

    # Get y_prediction
    y_batch = []
    Q_batch = output_target.eval(feed_dict = {x_image: observation_next_batch})
    for i in range(len(minibatch)):
        if terminal_batch[i] == True:
            y_batch.append(reward_batch[i])
        else:
            y_batch.append(reward_batch[i] + Gamma * np.max(Q_batch[i]))

    _, loss = sess.run([train_step, Loss], feed_dict = {action_target: action_batch, y_target: y_batch, x_image: observation_batch})

# Experience Replay 
def Experience_Replay(progress, Replay_memory, observation_stack, action, reward, next_observation_stack, terminal):
    if progress != 'Testing':
        # If length of replay memeory is more than the setting value then remove the first one
        if len(Replay_memory) > Num_replay_memory:
            del Replay_memory[0]

        # Save experience to the Replay memory
        Replay_memory.append([observation_stack, action, reward, next_observation_stack, terminal])
    else:
        # Empty the replay memory if testing
        Replay_memory = []
    
    return Replay_memory

# %% [markdown]
# ### Initialize Variables and network

# %%
# Initial parameters
Replay_memory = []
step = 1
score = 0
score_board = 0

episode = 0
step_per_episode = 0

train_mode = True
env_info = env.reset(train_mode=train_mode)[default_brain]

observation_stack, observation_set = input_initialization(env_info)

# %% [markdown]
# ### Training

# %%
check_plot = 0

# Training & Testing
while True:
    
    # Get Progress, train mode
    progress, train_mode, Epsilon  = get_progress(step, Epsilon)
    
    # Select Actions 
    action, Q_value = select_action(progress, sess, observation_stack, Epsilon)
    action_in = [np.argmax(action)]

    # Get information for update
    env_info = env.step(action_in)[default_brain]

    next_observation_stack, observation_set = resize_input(env_info, observation_set) 
    reward = env_info.rewards[0]
    terminal = env_info.local_done[0]
    
    if progress == 'Training':
        # Train!! 
        train(Replay_memory, sess, step)

        # Save the variables to disk.
        if step == Num_start_training + Num_training:
            save_path = saver.save(sess, 'saved_networks/' + date_time + '_' + algorithm + "/model.ckpt")
            print("Model saved in file: %s" % save_path)
    
    # If progress is finished -> close! 
    if progress == 'Finished':
        print('Finished!!')
        env.close()
        break
        
    Replay_memory = Experience_Replay(progress, Replay_memory, observation_stack, action, reward, next_observation_stack, terminal)
    
    # Update information
    step += 1
    score += reward
    step_per_episode += 1
    observation_stack = next_observation_stack
    
    # Update tensorboard
    if progress != 'Observing':
        if episode % Num_plot_episode == 0 and check_plot == 1 and episode != 0:
            tensorboard_info = [score_board / Num_plot_episode]
            for i in range(len(tensorboard_info)):
                sess.run(update_ops[i], feed_dict = {summary_placeholders[i]: float(tensorboard_info[i])})
            summary_str = sess.run(summary_op)
            summary_writer.add_summary(summary_str, step)
            score_board = 0
            check_plot = 0
            
    # If terminal is True
    if terminal == True:
        # Print informations
        print('step: ' + str(step) + ' / '  + 'episode: ' + str(episode) + ' / ' + 'progress: ' + progress  + ' / ' + 'epsilon: ' + str(Epsilon)  +' / ' + 'score: ' + str(score))

        check_plot = 1

        if progress != 'Observing':
            episode += 1
            
            score_board += score
            
        score = 0
        step_per_episode = 0

        # Initialize game state
        env_info = env.reset(train_mode=train_mode)[default_brain]
        observation_stack, observation_set = input_initialization(env_info)
# Out:
# step: 171 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 233 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 295 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 357 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 527 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 589 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 759 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 821 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 883 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 1161 / episode: 0 / progress: Observing / epsilon: 1 / score: 0.0
# step: 1655 / episode: 0 / progress: Observing / epsilon: 1 / score: 1.0
# step: 1825 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 1887 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 1949 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 2119 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 2181 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 2351 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 2413 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 2583 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 2861 / episode: 0 / progress: Observing / epsilon: 1 / score: 0.0
# step: 3031 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 3633 / episode: 0 / progress: Observing / epsilon: 1 / score: 1.0
# step: 3695 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 3865 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 4035 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 4853 / episode: 0 / progress: Observing / epsilon: 1 / score: 2.0
# step: 4915 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 4977 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 5147 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 5209 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 5379 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 5441 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 5611 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 5781 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 5843 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 6445 / episode: 0 / progress: Observing / epsilon: 1 / score: 1.0
# step: 7155 / episode: 0 / progress: Observing / epsilon: 1 / score: 2.0
# step: 7217 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 7387 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 7557 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 7943 / episode: 0 / progress: Observing / epsilon: 1 / score: 0.0
# step: 8437 / episode: 0 / progress: Observing / epsilon: 1 / score: 1.0
# step: 8499 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 8561 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 8731 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 8898 / episode: 0 / progress: Observing / epsilon: 1 / score: 5.0
# step: 8960 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 9130 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 9300 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 9470 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 9856 / episode: 0 / progress: Observing / epsilon: 1 / score: 0.0
# step: 9918 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 10088 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 10258 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 10428 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 10490 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 10660 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 10830 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 10892 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 11062 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 11232 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 11291 / episode: 0 / progress: Observing / epsilon: 1 / score: 5.0
# step: 11461 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 11523 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 11693 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 11971 / episode: 0 / progress: Observing / epsilon: 1 / score: 0.0
# step: 12033 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 12095 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 12157 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 12324 / episode: 0 / progress: Observing / epsilon: 1 / score: 5.0
# step: 12386 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 12556 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 12726 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 12788 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 12958 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 13236 / episode: 0 / progress: Observing / epsilon: 1 / score: 0.0
# step: 13406 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 13792 / episode: 0 / progress: Observing / epsilon: 1 / score: 0.0
# step: 13962 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 14240 / episode: 0 / progress: Observing / epsilon: 1 / score: 0.0
# step: 14410 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 14580 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 14642 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 14812 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 14982 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 15152 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 15538 / episode: 0 / progress: Observing / epsilon: 1 / score: 0.0
# step: 15708 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 15878 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 15940 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 16002 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 16172 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 16234 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 16296 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 16358 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 16528 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 16698 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 16760 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 17578 / episode: 0 / progress: Observing / epsilon: 1 / score: 2.0
# step: 17640 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 18134 / episode: 0 / progress: Observing / epsilon: 1 / score: 1.0
# step: 18304 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 18366 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 18536 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 18706 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 18768 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 18830 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 18892 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 18954 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 19016 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 19618 / episode: 0 / progress: Observing / epsilon: 1 / score: 1.0
# step: 19677 / episode: 0 / progress: Observing / epsilon: 1 / score: 5.0
# step: 19847 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 20017 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 20079 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 20141 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 20203 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 20265 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 20435 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 20497 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 20559 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 20729 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 20899 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 21069 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 21455 / episode: 0 / progress: Observing / epsilon: 1 / score: 0.0
# step: 21517 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 21903 / episode: 0 / progress: Observing / epsilon: 1 / score: 0.0
# step: 22073 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 22243 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 22521 / episode: 0 / progress: Observing / epsilon: 1 / score: 0.0
# step: 22691 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 22861 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 23139 / episode: 0 / progress: Observing / epsilon: 1 / score: 0.0
# step: 23309 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 23371 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 23541 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 23711 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 24313 / episode: 0 / progress: Observing / epsilon: 1 / score: 1.0
# step: 24483 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 24545 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 24607 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 24777 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 24947 / episode: 0 / progress: Observing / epsilon: 1 / score: -1.0
# step: 25009 / episode: 0 / progress: Training / epsilon: 0.9999840000000004 / score: -1.0
# step: 25071 / episode: 1 / progress: Training / epsilon: 0.9998600000000037 / score: -1.0
# step: 25241 / episode: 2 / progress: Training / epsilon: 0.9995200000000128 / score: -1.0
# step: 25843 / episode: 3 / progress: Training / epsilon: 0.9983160000000451 / score: 1.0
# step: 26013 / episode: 4 / progress: Training / epsilon: 0.9979760000000542 / score: -1.0
# step: 26183 / episode: 5 / progress: Training / epsilon: 0.9976360000000632 / score: -1.0
# step: 26245 / episode: 6 / progress: Training / epsilon: 0.9975120000000666 / score: -1.0
# step: 26415 / episode: 7 / progress: Training / epsilon: 0.9971720000000757 / score: -1.0
# step: 26477 / episode: 8 / progress: Training / epsilon: 0.997048000000079 / score: -1.0
# step: 26539 / episode: 9 / progress: Training / epsilon: 0.9969240000000823 / score: -1.0
# step: 26709 / episode: 10 / progress: Training / epsilon: 0.9965840000000914 / score: -1.0
# step: 26879 / episode: 11 / progress: Training / epsilon: 0.9962440000001005 / score: -1.0
# step: 27805 / episode: 12 / progress: Training / epsilon: 0.99439200000015 / score: 3.0
# step: 27867 / episode: 13 / progress: Training / epsilon: 0.9942680000001534 / score: -1.0
# step: 28037 / episode: 14 / progress: Training / epsilon: 0.9939280000001625 / score: -1.0
# step: 28099 / episode: 15 / progress: Training / epsilon: 0.9938040000001658 / score: -1.0
# step: 28269 / episode: 16 / progress: Training / epsilon: 0.9934640000001749 / score: -1.0
# step: 28439 / episode: 17 / progress: Training / epsilon: 0.993124000000184 / score: -1.0
# step: 28501 / episode: 18 / progress: Training / epsilon: 0.9930000000001873 / score: -1.0
# step: 28671 / episode: 19 / progress: Training / epsilon: 0.9926600000001964 / score: -1.0
# step: 28841 / episode: 20 / progress: Training / epsilon: 0.9923200000002055 / score: -1.0
# step: 29119 / episode: 21 / progress: Training / epsilon: 0.9917640000002204 / score: 0.0
# step: 29181 / episode: 22 / progress: Training / epsilon: 0.9916400000002237 / score: -1.0
# step: 29243 / episode: 23 / progress: Training / epsilon: 0.991516000000227 / score: -1.0
# step: 29413 / episode: 24 / progress: Training / epsilon: 0.9911760000002361 / score: -1.0
# step: 29475 / episode: 25 / progress: Training / epsilon: 0.9910520000002394 / score: -1.0
# step: 29537 / episode: 26 / progress: Training / epsilon: 0.9909280000002427 / score: -1.0
# step: 29599 / episode: 27 / progress: Training / epsilon: 0.990804000000246 / score: -1.0
# step: 29661 / episode: 28 / progress: Training / epsilon: 0.9906800000002494 / score: -1.0
# step: 30047 / episode: 29 / progress: Training / epsilon: 0.98990800000027 / score: 0.0
# step: 30649 / episode: 30 / progress: Training / epsilon: 0.9887040000003022 / score: 1.0
# step: 30819 / episode: 31 / progress: Training / epsilon: 0.9883640000003113 / score: -1.0
# step: 30881 / episode: 32 / progress: Training / epsilon: 0.9882400000003146 / score: -1.0
# step: 30943 / episode: 33 / progress: Training / epsilon: 0.988116000000318 / score: -1.0
# step: 31113 / episode: 34 / progress: Training / epsilon: 0.9877760000003271 / score: -1.0
# step: 31283 / episode: 35 / progress: Training / epsilon: 0.9874360000003362 / score: -1.0
# step: 31453 / episode: 36 / progress: Training / epsilon: 0.9870960000003453 / score: -1.0
# step: 31623 / episode: 37 / progress: Training / epsilon: 0.9867560000003543 / score: -1.0
# step: 32009 / episode: 38 / progress: Training / epsilon: 0.985984000000375 / score: 0.0
# step: 32503 / episode: 39 / progress: Training / epsilon: 0.9849960000004014 / score: 1.0
# step: 32565 / episode: 40 / progress: Training / epsilon: 0.9848720000004048 / score: -1.0
# step: 32735 / episode: 41 / progress: Training / epsilon: 0.9845320000004139 / score: -1.0
# step: 32797 / episode: 42 / progress: Training / epsilon: 0.9844080000004172 / score: -1.0
# step: 32967 / episode: 43 / progress: Training / epsilon: 0.9840680000004263 / score: -1.0
# step: 33353 / episode: 44 / progress: Training / epsilon: 0.9832960000004469 / score: 0.0
# step: 33739 / episode: 45 / progress: Training / epsilon: 0.9825240000004676 / score: 0.0
# step: 33909 / episode: 46 / progress: Training / epsilon: 0.9821840000004767 / score: -1.0
# step: 34079 / episode: 47 / progress: Training / epsilon: 0.9818440000004858 / score: -1.0
# step: 34249 / episode: 48 / progress: Training / epsilon: 0.9815040000004949 / score: -1.0
# step: 34635 / episode: 49 / progress: Training / epsilon: 0.9807320000005155 / score: 0.0
# step: 34805 / episode: 50 / progress: Training / epsilon: 0.9803920000005246 / score: -1.0
# step: 34867 / episode: 51 / progress: Training / epsilon: 0.9802680000005279 / score: -1.0
# step: 35037 / episode: 52 / progress: Training / epsilon: 0.979928000000537 / score: -1.0
# step: 35423 / episode: 53 / progress: Training / epsilon: 0.9791560000005577 / score: 0.0
# step: 35593 / episode: 54 / progress: Training / epsilon: 0.9788160000005668 / score: -1.0
# step: 35763 / episode: 55 / progress: Training / epsilon: 0.9784760000005759 / score: -1.0
# step: 35933 / episode: 56 / progress: Training / epsilon: 0.978136000000585 / score: -1.0
# step: 36103 / episode: 57 / progress: Training / epsilon: 0.9777960000005941 / score: -1.0
# step: 36273 / episode: 58 / progress: Training / epsilon: 0.9774560000006032 / score: -1.0
# step: 36443 / episode: 59 / progress: Training / epsilon: 0.9771160000006123 / score: -1.0
# step: 36613 / episode: 60 / progress: Training / epsilon: 0.9767760000006214 / score: -1.0
# step: 37431 / episode: 61 / progress: Training / epsilon: 0.9751400000006651 / score: 2.0
# step: 37493 / episode: 62 / progress: Training / epsilon: 0.9750160000006685 / score: -1.0
# step: 37555 / episode: 63 / progress: Training / epsilon: 0.9748920000006718 / score: -1.0
# step: 37617 / episode: 64 / progress: Training / epsilon: 0.9747680000006751 / score: -1.0
# step: 37679 / episode: 65 / progress: Training / epsilon: 0.9746440000006784 / score: -1.0
# step: 37741 / episode: 66 / progress: Training / epsilon: 0.9745200000006817 / score: -1.0
# step: 37911 / episode: 67 / progress: Training / epsilon: 0.9741800000006908 / score: -1.0
# step: 38081 / episode: 68 / progress: Training / epsilon: 0.9738400000006999 / score: -1.0
# step: 38251 / episode: 69 / progress: Training / epsilon: 0.973500000000709 / score: -1.0
# step: 38421 / episode: 70 / progress: Training / epsilon: 0.9731600000007181 / score: -1.0
# step: 38483 / episode: 71 / progress: Training / epsilon: 0.9730360000007214 / score: -1.0
# step: 38653 / episode: 72 / progress: Training / epsilon: 0.9726960000007305 / score: -1.0
# step: 38715 / episode: 73 / progress: Training / epsilon: 0.9725720000007338 / score: -1.0
# step: 38885 / episode: 74 / progress: Training / epsilon: 0.972232000000743 / score: -1.0
# step: 39055 / episode: 75 / progress: Training / epsilon: 0.971892000000752 / score: -1.0
# step: 39117 / episode: 76 / progress: Training / epsilon: 0.9717680000007554 / score: -1.0
# step: 39179 / episode: 77 / progress: Training / epsilon: 0.9716440000007587 / score: -1.0
# step: 39241 / episode: 78 / progress: Training / epsilon: 0.971520000000762 / score: -1.0
# step: 39300 / episode: 79 / progress: Training / epsilon: 0.9714020000007652 / score: 5.0
# step: 39470 / episode: 80 / progress: Training / epsilon: 0.9710620000007743 / score: -1.0
# step: 39640 / episode: 81 / progress: Training / epsilon: 0.9707220000007833 / score: -1.0
# step: 39810 / episode: 82 / progress: Training / epsilon: 0.9703820000007924 / score: -1.0
# step: 40196 / episode: 83 / progress: Training / epsilon: 0.9696100000008131 / score: 0.0
# step: 40258 / episode: 84 / progress: Training / epsilon: 0.9694860000008164 / score: -1.0
# step: 40428 / episode: 85 / progress: Training / epsilon: 0.9691460000008255 / score: -1.0
# step: 40490 / episode: 86 / progress: Training / epsilon: 0.9690220000008288 / score: -1.0
# step: 40876 / episode: 87 / progress: Training / epsilon: 0.9682500000008495 / score: 0.0
# step: 40938 / episode: 88 / progress: Training / epsilon: 0.9681260000008528 / score: -1.0
# step: 41324 / episode: 89 / progress: Training / epsilon: 0.9673540000008735 / score: 0.0
# step: 41386 / episode: 90 / progress: Training / epsilon: 0.9672300000008768 / score: -1.0
# step: 41448 / episode: 91 / progress: Training / epsilon: 0.9671060000008801 / score: -1.0
# step: 41942 / episode: 92 / progress: Training / epsilon: 0.9661180000009065 / score: 1.0
# step: 42004 / episode: 93 / progress: Training / epsilon: 0.9659940000009098 / score: -1.0
# step: 42174 / episode: 94 / progress: Training / epsilon: 0.9656540000009189 / score: -1.0
# step: 42344 / episode: 95 / progress: Training / epsilon: 0.965314000000928 / score: -1.0
# step: 42514 / episode: 96 / progress: Training / epsilon: 0.9649740000009371 / score: -1.0
# step: 42576 / episode: 97 / progress: Training / epsilon: 0.9648500000009405 / score: -1.0
# step: 42746 / episode: 98 / progress: Training / epsilon: 0.9645100000009496 / score: -1.0
# step: 42916 / episode: 99 / progress: Training / epsilon: 0.9641700000009586 / score: -1.0
# step: 42978 / episode: 100 / progress: Training / epsilon: 0.964046000000962 / score: -1.0
# step: 43040 / episode: 101 / progress: Training / epsilon: 0.9639220000009653 / score: -1.0
# step: 43430 / episode: 102 / progress: Training / epsilon: 0.9631420000009862 / score: 2.0
# step: 43492 / episode: 103 / progress: Training / epsilon: 0.9630180000009895 / score: -1.0
# step: 43662 / episode: 104 / progress: Training / epsilon: 0.9626780000009986 / score: -1.0
# step: 43724 / episode: 105 / progress: Training / epsilon: 0.9625540000010019 / score: -1.0
# step: 44218 / episode: 106 / progress: Training / epsilon: 0.9615660000010283 / score: 1.0
# step: 44388 / episode: 107 / progress: Training / epsilon: 0.9612260000010374 / score: -1.0
# step: 44450 / episode: 108 / progress: Training / epsilon: 0.9611020000010407 / score: -1.0
# step: 44620 / episode: 109 / progress: Training / epsilon: 0.9607620000010498 / score: -1.0
# step: 44682 / episode: 110 / progress: Training / epsilon: 0.9606380000010531 / score: -1.0
# step: 44744 / episode: 111 / progress: Training / epsilon: 0.9605140000010565 / score: -1.0
# step: 44914 / episode: 112 / progress: Training / epsilon: 0.9601740000010656 / score: -1.0
# step: 44976 / episode: 113 / progress: Training / epsilon: 0.9600500000010689 / score: -1.0
# step: 45038 / episode: 114 / progress: Training / epsilon: 0.9599260000010722 / score: -1.0
# step: 45208 / episode: 115 / progress: Training / epsilon: 0.9595860000010813 / score: -1.0
# step: 45918 / episode: 116 / progress: Training / epsilon: 0.9581660000011193 / score: 2.0
# step: 45980 / episode: 117 / progress: Training / epsilon: 0.9580420000011226 / score: -1.0
# step: 46150 / episode: 118 / progress: Training / epsilon: 0.9577020000011317 / score: -1.0
# step: 46212 / episode: 119 / progress: Training / epsilon: 0.957578000001135 / score: -1.0
# step: 46598 / episode: 120 / progress: Training / epsilon: 0.9568060000011557 / score: 0.0
# step: 46984 / episode: 121 / progress: Training / epsilon: 0.9560340000011763 / score: 0.0
# step: 47046 / episode: 122 / progress: Training / epsilon: 0.9559100000011796 / score: -1.0
# step: 47108 / episode: 123 / progress: Training / epsilon: 0.955786000001183 / score: -1.0
# step: 47494 / episode: 124 / progress: Training / epsilon: 0.9550140000012036 / score: 0.0
# step: 47556 / episode: 125 / progress: Training / epsilon: 0.9548900000012069 / score: -1.0
# step: 47618 / episode: 126 / progress: Training / epsilon: 0.9547660000012103 / score: -1.0
# step: 47788 / episode: 127 / progress: Training / epsilon: 0.9544260000012194 / score: -1.0
# step: 47958 / episode: 128 / progress: Training / epsilon: 0.9540860000012285 / score: -1.0
# step: 48128 / episode: 129 / progress: Training / epsilon: 0.9537460000012375 / score: -1.0
# step: 48298 / episode: 130 / progress: Training / epsilon: 0.9534060000012466 / score: -1.0
# step: 48468 / episode: 131 / progress: Training / epsilon: 0.9530660000012557 / score: -1.0
# step: 48530 / episode: 132 / progress: Training / epsilon: 0.9529420000012591 / score: -1.0
# step: 48592 / episode: 133 / progress: Training / epsilon: 0.9528180000012624 / score: -1.0
# step: 48654 / episode: 134 / progress: Training / epsilon: 0.9526940000012657 / score: -1.0
# step: 48932 / episode: 135 / progress: Training / epsilon: 0.9521380000012806 / score: 0.0
# step: 49318 / episode: 136 / progress: Training / epsilon: 0.9513660000013012 / score: 0.0
# step: 49920 / episode: 137 / progress: Training / epsilon: 0.9501620000013334 / score: 1.0
# step: 50090 / episode: 138 / progress: Training / epsilon: 0.9498220000013425 / score: -1.0
# step: 50260 / episode: 139 / progress: Training / epsilon: 0.9494820000013516 / score: -1.0
# step: 50430 / episode: 140 / progress: Training / epsilon: 0.9491420000013607 / score: -1.0
# step: 50600 / episode: 141 / progress: Training / epsilon: 0.9488020000013698 / score: -1.0
# step: 50986 / episode: 142 / progress: Training / epsilon: 0.9480300000013905 / score: 0.0
# step: 51048 / episode: 143 / progress: Training / epsilon: 0.9479060000013938 / score: -1.0
# step: 51107 / episode: 144 / progress: Training / epsilon: 0.947788000001397 / score: 5.0
# step: 51274 / episode: 145 / progress: Training / epsilon: 0.9474540000014059 / score: 5.0
# step: 51660 / episode: 146 / progress: Training / epsilon: 0.9466820000014265 / score: 0.0
# step: 51722 / episode: 147 / progress: Training / epsilon: 0.9465580000014299 / score: -1.0
# step: 51784 / episode: 148 / progress: Training / epsilon: 0.9464340000014332 / score: -1.0
# step: 51846 / episode: 149 / progress: Training / epsilon: 0.9463100000014365 / score: -1.0
# step: 52016 / episode: 150 / progress: Training / epsilon: 0.9459700000014456 / score: -1.0
# step: 52078 / episode: 151 / progress: Training / epsilon: 0.9458460000014489 / score: -1.0
# step: 52464 / episode: 152 / progress: Training / epsilon: 0.9450740000014696 / score: 0.0
# step: 52634 / episode: 153 / progress: Training / epsilon: 0.9447340000014787 / score: -1.0
# step: 52804 / episode: 154 / progress: Training / epsilon: 0.9443940000014878 / score: -1.0
# step: 52974 / episode: 155 / progress: Training / epsilon: 0.9440540000014969 / score: -1.0
# step: 53036 / episode: 156 / progress: Training / epsilon: 0.9439300000015002 / score: -1.0
# step: 53206 / episode: 157 / progress: Training / epsilon: 0.9435900000015093 / score: -1.0
# step: 53376 / episode: 158 / progress: Training / epsilon: 0.9432500000015184 / score: -1.0
# step: 53546 / episode: 159 / progress: Training / epsilon: 0.9429100000015275 / score: -1.0
# step: 53608 / episode: 160 / progress: Training / epsilon: 0.9427860000015308 / score: -1.0
# step: 53670 / episode: 161 / progress: Training / epsilon: 0.9426620000015341 / score: -1.0
# step: 53840 / episode: 162 / progress: Training / epsilon: 0.9423220000015432 / score: -1.0
# step: 53902 / episode: 163 / progress: Training / epsilon: 0.9421980000015465 / score: -1.0
# step: 53964 / episode: 164 / progress: Training / epsilon: 0.9420740000015498 / score: -1.0
# step: 54134 / episode: 165 / progress: Training / epsilon: 0.9417340000015589 / score: -1.0
# step: 54196 / episode: 166 / progress: Training / epsilon: 0.9416100000015623 / score: -1.0
# step: 54690 / episode: 167 / progress: Training / epsilon: 0.9406220000015887 / score: 1.0
# step: 55076 / episode: 168 / progress: Training / epsilon: 0.9398500000016093 / score: 0.0
# step: 55462 / episode: 169 / progress: Training / epsilon: 0.93907800000163 / score: 0.0
# step: 55524 / episode: 170 / progress: Training / epsilon: 0.9389540000016333 / score: -1.0
# step: 55586 / episode: 171 / progress: Training / epsilon: 0.9388300000016366 / score: -1.0
# step: 55648 / episode: 172 / progress: Training / epsilon: 0.93870600000164 / score: -1.0
# step: 55818 / episode: 173 / progress: Training / epsilon: 0.938366000001649 / score: -1.0
# step: 55880 / episode: 174 / progress: Training / epsilon: 0.9382420000016524 / score: -1.0
# step: 56050 / episode: 175 / progress: Training / epsilon: 0.9379020000016615 / score: -1.0
# step: 56436 / episode: 176 / progress: Training / epsilon: 0.9371300000016821 / score: 0.0
# step: 56498 / episode: 177 / progress: Training / epsilon: 0.9370060000016854 / score: -1.0
# step: 56668 / episode: 178 / progress: Training / epsilon: 0.9366660000016945 / score: -1.0
# step: 56838 / episode: 179 / progress: Training / epsilon: 0.9363260000017036 / score: -1.0
# step: 56900 / episode: 180 / progress: Training / epsilon: 0.936202000001707 / score: -1.0
# step: 57178 / episode: 181 / progress: Training / epsilon: 0.9356460000017218 / score: 0.0
# step: 57564 / episode: 182 / progress: Training / epsilon: 0.9348740000017425 / score: 0.0
# step: 57626 / episode: 183 / progress: Training / epsilon: 0.9347500000017458 / score: -1.0
# step: 57688 / episode: 184 / progress: Training / epsilon: 0.9346260000017491 / score: -1.0
# step: 57750 / episode: 185 / progress: Training / epsilon: 0.9345020000017524 / score: -1.0
# step: 58136 / episode: 186 / progress: Training / epsilon: 0.9337300000017731 / score: 0.0
# step: 58198 / episode: 187 / progress: Training / epsilon: 0.9336060000017764 / score: -1.0
# step: 58368 / episode: 188 / progress: Training / epsilon: 0.9332660000017855 / score: -1.0
# step: 58430 / episode: 189 / progress: Training / epsilon: 0.9331420000017888 / score: -1.0
# step: 58600 / episode: 190 / progress: Training / epsilon: 0.9328020000017979 / score: -1.0
# step: 58662 / episode: 191 / progress: Training / epsilon: 0.9326780000018012 / score: -1.0
# step: 59048 / episode: 192 / progress: Training / epsilon: 0.9319060000018219 / score: 0.0
# step: 59218 / episode: 193 / progress: Training / epsilon: 0.931566000001831 / score: -1.0
# step: 59388 / episode: 194 / progress: Training / epsilon: 0.9312260000018401 / score: -1.0
# step: 59882 / episode: 195 / progress: Training / epsilon: 0.9302380000018665 / score: 1.0
# step: 59944 / episode: 196 / progress: Training / epsilon: 0.9301140000018698 / score: -1.0
# step: 60114 / episode: 197 / progress: Training / epsilon: 0.9297740000018789 / score: -1.0
# step: 60176 / episode: 198 / progress: Training / epsilon: 0.9296500000018822 / score: -1.0
# step: 60346 / episode: 199 / progress: Training / epsilon: 0.9293100000018913 / score: -1.0
# step: 60948 / episode: 200 / progress: Training / epsilon: 0.9281060000019236 / score: 1.0
# step: 61226 / episode: 201 / progress: Training / epsilon: 0.9275500000019384 / score: 0.0
# step: 61828 / episode: 202 / progress: Training / epsilon: 0.9263460000019706 / score: 1.0
# step: 61890 / episode: 203 / progress: Training / epsilon: 0.926222000001974 / score: -1.0
# step: 61952 / episode: 204 / progress: Training / epsilon: 0.9260980000019773 / score: -1.0
# step: 62014 / episode: 205 / progress: Training / epsilon: 0.9259740000019806 / score: -1.0
# step: 62076 / episode: 206 / progress: Training / epsilon: 0.9258500000019839 / score: -1.0
# step: 62246 / episode: 207 / progress: Training / epsilon: 0.925510000001993 / score: -1.0
# step: 62308 / episode: 208 / progress: Training / epsilon: 0.9253860000019963 / score: -1.0
# step: 62586 / episode: 209 / progress: Training / epsilon: 0.9248300000020112 / score: 0.0
# step: 62860 / episode: 210 / progress: Training / epsilon: 0.9242820000020259 / score: 5.0
# step: 62922 / episode: 211 / progress: Training / epsilon: 0.9241580000020292 / score: -1.0
# step: 63200 / episode: 212 / progress: Training / epsilon: 0.9236020000020441 / score: 0.0
# step: 63367 / episode: 213 / progress: Training / epsilon: 0.923268000002053 / score: 5.0
# step: 63537 / episode: 214 / progress: Training / epsilon: 0.9229280000020621 / score: -1.0
# step: 63707 / episode: 215 / progress: Training / epsilon: 0.9225880000020712 / score: -1.0
# step: 63877 / episode: 216 / progress: Training / epsilon: 0.9222480000020803 / score: -1.0
# step: 63939 / episode: 217 / progress: Training / epsilon: 0.9221240000020836 / score: -1.0
# step: 64001 / episode: 218 / progress: Training / epsilon: 0.9220000000020869 / score: -1.0
# step: 64171 / episode: 219 / progress: Training / epsilon: 0.921660000002096 / score: -1.0
# step: 64341 / episode: 220 / progress: Training / epsilon: 0.9213200000021051 / score: -1.0
# step: 64511 / episode: 221 / progress: Training / epsilon: 0.9209800000021142 / score: -1.0
# step: 64897 / episode: 222 / progress: Training / epsilon: 0.9202080000021349 / score: 0.0
# step: 64959 / episode: 223 / progress: Training / epsilon: 0.9200840000021382 / score: -1.0
# step: 65021 / episode: 224 / progress: Training / epsilon: 0.9199600000021415 / score: -1.0
# step: 65083 / episode: 225 / progress: Training / epsilon: 0.9198360000021448 / score: -1.0
# step: 65145 / episode: 226 / progress: Training / epsilon: 0.9197120000021481 / score: -1.0
# step: 65315 / episode: 227 / progress: Training / epsilon: 0.9193720000021572 / score: -1.0
# step: 65485 / episode: 228 / progress: Training / epsilon: 0.9190320000021663 / score: -1.0
# step: 65655 / episode: 229 / progress: Training / epsilon: 0.9186920000021754 / score: -1.0
# step: 65825 / episode: 230 / progress: Training / epsilon: 0.9183520000021845 / score: -1.0
# step: 65995 / episode: 231 / progress: Training / epsilon: 0.9180120000021936 / score: -1.0
# step: 66165 / episode: 232 / progress: Training / epsilon: 0.9176720000022027 / score: -1.0
# step: 66335 / episode: 233 / progress: Training / epsilon: 0.9173320000022118 / score: -1.0
# step: 66397 / episode: 234 / progress: Training / epsilon: 0.9172080000022151 / score: -1.0
# step: 66783 / episode: 235 / progress: Training / epsilon: 0.9164360000022358 / score: 0.0
# step: 66845 / episode: 236 / progress: Training / epsilon: 0.9163120000022391 / score: -1.0
# step: 67339 / episode: 237 / progress: Training / epsilon: 0.9153240000022655 / score: 1.0
# step: 67401 / episode: 238 / progress: Training / epsilon: 0.9152000000022689 / score: -1.0
# step: 67463 / episode: 239 / progress: Training / epsilon: 0.9150760000022722 / score: -1.0
# step: 67633 / episode: 240 / progress: Training / epsilon: 0.9147360000022813 / score: -1.0
# step: 67803 / episode: 241 / progress: Training / epsilon: 0.9143960000022904 / score: -1.0
# step: 67973 / episode: 242 / progress: Training / epsilon: 0.9140560000022995 / score: -1.0
# step: 68143 / episode: 243 / progress: Training / epsilon: 0.9137160000023086 / score: -1.0
# step: 68313 / episode: 244 / progress: Training / epsilon: 0.9133760000023177 / score: -1.0
# step: 68375 / episode: 245 / progress: Training / epsilon: 0.913252000002321 / score: -1.0
# step: 68761 / episode: 246 / progress: Training / epsilon: 0.9124800000023416 / score: 0.0
# step: 68823 / episode: 247 / progress: Training / epsilon: 0.912356000002345 / score: -1.0
# step: 69101 / episode: 248 / progress: Training / epsilon: 0.9118000000023598 / score: 0.0
# step: 69487 / episode: 249 / progress: Training / epsilon: 0.9110280000023805 / score: 0.0
# step: 69549 / episode: 250 / progress: Training / epsilon: 0.9109040000023838 / score: -1.0
# step: 69719 / episode: 251 / progress: Training / epsilon: 0.9105640000023929 / score: -1.0
# step: 69781 / episode: 252 / progress: Training / epsilon: 0.9104400000023962 / score: -1.0
# step: 69843 / episode: 253 / progress: Training / epsilon: 0.9103160000023995 / score: -1.0
# step: 70121 / episode: 254 / progress: Training / epsilon: 0.9097600000024144 / score: 0.0
# step: 70183 / episode: 255 / progress: Training / epsilon: 0.9096360000024177 / score: -1.0
# step: 70245 / episode: 256 / progress: Training / epsilon: 0.909512000002421 / score: -1.0
# step: 70415 / episode: 257 / progress: Training / epsilon: 0.9091720000024301 / score: -1.0
# step: 70477 / episode: 258 / progress: Training / epsilon: 0.9090480000024335 / score: -1.0
# step: 70647 / episode: 259 / progress: Training / epsilon: 0.9087080000024426 / score: -1.0
# step: 70817 / episode: 260 / progress: Training / epsilon: 0.9083680000024517 / score: -1.0
# step: 70987 / episode: 261 / progress: Training / epsilon: 0.9080280000024608 / score: -1.0
# step: 71157 / episode: 262 / progress: Training / epsilon: 0.9076880000024699 / score: -1.0
# step: 71219 / episode: 263 / progress: Training / epsilon: 0.9075640000024732 / score: -1.0
# step: 71281 / episode: 264 / progress: Training / epsilon: 0.9074400000024765 / score: -1.0
# step: 71451 / episode: 265 / progress: Training / epsilon: 0.9071000000024856 / score: -1.0
# step: 71513 / episode: 266 / progress: Training / epsilon: 0.9069760000024889 / score: -1.0
# step: 71791 / episode: 267 / progress: Training / epsilon: 0.9064200000025038 / score: 0.0
# step: 72069 / episode: 268 / progress: Training / epsilon: 0.9058640000025187 / score: 0.0
# step: 72563 / episode: 269 / progress: Training / epsilon: 0.9048760000025451 / score: 1.0
# step: 72733 / episode: 270 / progress: Training / epsilon: 0.9045360000025542 / score: -1.0
# step: 73011 / episode: 271 / progress: Training / epsilon: 0.9039800000025691 / score: 0.0
# step: 73181 / episode: 272 / progress: Training / epsilon: 0.9036400000025782 / score: -1.0
# step: 73351 / episode: 273 / progress: Training / epsilon: 0.9033000000025873 / score: -1.0
# step: 73521 / episode: 274 / progress: Training / epsilon: 0.9029600000025964 / score: -1.0
# step: 73799 / episode: 275 / progress: Training / epsilon: 0.9024040000026112 / score: 0.0
# step: 73969 / episode: 276 / progress: Training / epsilon: 0.9020640000026203 / score: -1.0
# step: 74355 / episode: 277 / progress: Training / epsilon: 0.901292000002641 / score: 0.0
# step: 74417 / episode: 278 / progress: Training / epsilon: 0.9011680000026443 / score: -1.0
# step: 74479 / episode: 279 / progress: Training / epsilon: 0.9010440000026476 / score: -1.0
# step: 74541 / episode: 280 / progress: Training / epsilon: 0.9009200000026509 / score: -1.0
# step: 75035 / episode: 281 / progress: Training / epsilon: 0.8999320000026774 / score: 1.0
# step: 75097 / episode: 282 / progress: Training / epsilon: 0.8998080000026807 / score: -1.0
# step: 75159 / episode: 283 / progress: Training / epsilon: 0.899684000002684 / score: -1.0
# step: 75545 / episode: 284 / progress: Training / epsilon: 0.8989120000027047 / score: 0.0
# step: 75931 / episode: 285 / progress: Training / epsilon: 0.8981400000027253 / score: 0.0
# step: 76101 / episode: 286 / progress: Training / epsilon: 0.8978000000027344 / score: -1.0
# step: 76271 / episode: 287 / progress: Training / epsilon: 0.8974600000027435 / score: -1.0
# step: 76549 / episode: 288 / progress: Training / epsilon: 0.8969040000027584 / score: 0.0
# step: 76611 / episode: 289 / progress: Training / epsilon: 0.8967800000027617 / score: -1.0
# step: 76781 / episode: 290 / progress: Training / epsilon: 0.8964400000027708 / score: -1.0
# step: 77163 / episode: 291 / progress: Training / epsilon: 0.8956760000027912 / score: 5.0
# step: 77225 / episode: 292 / progress: Training / epsilon: 0.8955520000027946 / score: -1.0
# step: 77287 / episode: 293 / progress: Training / epsilon: 0.8954280000027979 / score: -1.0
# step: 77457 / episode: 294 / progress: Training / epsilon: 0.895088000002807 / score: -1.0
# step: 77519 / episode: 295 / progress: Training / epsilon: 0.8949640000028103 / score: -1.0
# step: 77581 / episode: 296 / progress: Training / epsilon: 0.8948400000028136 / score: -1.0
# step: 77643 / episode: 297 / progress: Training / epsilon: 0.8947160000028169 / score: -1.0
# step: 77705 / episode: 298 / progress: Training / epsilon: 0.8945920000028202 / score: -1.0
# step: 77875 / episode: 299 / progress: Training / epsilon: 0.8942520000028293 / score: -1.0
# step: 78045 / episode: 300 / progress: Training / epsilon: 0.8939120000028384 / score: -1.0
# step: 78323 / episode: 301 / progress: Training / epsilon: 0.8933560000028533 / score: 0.0
# step: 78493 / episode: 302 / progress: Training / epsilon: 0.8930160000028624 / score: -1.0
# step: 78663 / episode: 303 / progress: Training / epsilon: 0.8926760000028715 / score: -1.0
# step: 78833 / episode: 304 / progress: Training / epsilon: 0.8923360000028806 / score: -1.0
# step: 79003 / episode: 305 / progress: Training / epsilon: 0.8919960000028897 / score: -1.0
# step: 79173 / episode: 306 / progress: Training / epsilon: 0.8916560000028988 / score: -1.0
# step: 79235 / episode: 307 / progress: Training / epsilon: 0.8915320000029021 / score: -1.0
# step: 79837 / episode: 308 / progress: Training / epsilon: 0.8903280000029343 / score: 1.0
# step: 79899 / episode: 309 / progress: Training / epsilon: 0.8902040000029376 / score: -1.0
# step: 79961 / episode: 310 / progress: Training / epsilon: 0.890080000002941 / score: -1.0
# step: 80023 / episode: 311 / progress: Training / epsilon: 0.8899560000029443 / score: -1.0
# step: 80193 / episode: 312 / progress: Training / epsilon: 0.8896160000029534 / score: -1.0
# step: 80255 / episode: 313 / progress: Training / epsilon: 0.8894920000029567 / score: -1.0
# step: 80425 / episode: 314 / progress: Training / epsilon: 0.8891520000029658 / score: -1.0
# step: 80703 / episode: 315 / progress: Training / epsilon: 0.8885960000029807 / score: 0.0
# step: 80873 / episode: 316 / progress: Training / epsilon: 0.8882560000029898 / score: -1.0
# step: 81151 / episode: 317 / progress: Training / epsilon: 0.8877000000030046 / score: 0.0
# step: 81537 / episode: 318 / progress: Training / epsilon: 0.8869280000030253 / score: 0.0
# step: 81599 / episode: 319 / progress: Training / epsilon: 0.8868040000030286 / score: -1.0
# step: 81661 / episode: 320 / progress: Training / epsilon: 0.8866800000030319 / score: -1.0
# step: 81831 / episode: 321 / progress: Training / epsilon: 0.886340000003041 / score: -1.0
# step: 82001 / episode: 322 / progress: Training / epsilon: 0.8860000000030501 / score: -1.0
# step: 82387 / episode: 323 / progress: Training / epsilon: 0.8852280000030708 / score: 0.0
# step: 82557 / episode: 324 / progress: Training / epsilon: 0.8848880000030799 / score: -1.0
# step: 82943 / episode: 325 / progress: Training / epsilon: 0.8841160000031005 / score: 0.0
# step: 83005 / episode: 326 / progress: Training / epsilon: 0.8839920000031039 / score: -1.0
# step: 83067 / episode: 327 / progress: Training / epsilon: 0.8838680000031072 / score: -1.0
# step: 83237 / episode: 328 / progress: Training / epsilon: 0.8835280000031163 / score: -1.0
# step: 83299 / episode: 329 / progress: Training / epsilon: 0.8834040000031196 / score: -1.0
# step: 83577 / episode: 330 / progress: Training / epsilon: 0.8828480000031345 / score: 0.0
# step: 83747 / episode: 331 / progress: Training / epsilon: 0.8825080000031436 / score: -1.0
# step: 83809 / episode: 332 / progress: Training / epsilon: 0.8823840000031469 / score: -1.0
# step: 83871 / episode: 333 / progress: Training / epsilon: 0.8822600000031502 / score: -1.0
# step: 84041 / episode: 334 / progress: Training / epsilon: 0.8819200000031593 / score: -1.0
# step: 84103 / episode: 335 / progress: Training / epsilon: 0.8817960000031626 / score: -1.0
# step: 84165 / episode: 336 / progress: Training / epsilon: 0.8816720000031659 / score: -1.0
# step: 84335 / episode: 337 / progress: Training / epsilon: 0.881332000003175 / score: -1.0
# step: 84397 / episode: 338 / progress: Training / epsilon: 0.8812080000031783 / score: -1.0
# step: 84459 / episode: 339 / progress: Training / epsilon: 0.8810840000031817 / score: -1.0
# step: 85277 / episode: 340 / progress: Training / epsilon: 0.8794480000032254 / score: 2.0
# step: 85665 / episode: 341 / progress: Training / epsilon: 0.8786720000032462 / score: 0.0
# step: 85724 / episode: 342 / progress: Training / epsilon: 0.8785540000032493 / score: 5.0
# step: 86002 / episode: 343 / progress: Training / epsilon: 0.8779980000032642 / score: 0.0
# step: 86172 / episode: 344 / progress: Training / epsilon: 0.8776580000032733 / score: -1.0
# step: 86558 / episode: 345 / progress: Training / epsilon: 0.876886000003294 / score: 0.0
# step: 86728 / episode: 346 / progress: Training / epsilon: 0.8765460000033031 / score: -1.0
# step: 86790 / episode: 347 / progress: Training / epsilon: 0.8764220000033064 / score: -1.0
# step: 86852 / episode: 348 / progress: Training / epsilon: 0.8762980000033097 / score: -1.0
# step: 87022 / episode: 349 / progress: Training / epsilon: 0.8759580000033188 / score: -1.0
# step: 87084 / episode: 350 / progress: Training / epsilon: 0.8758340000033221 / score: -1.0
# step: 87146 / episode: 351 / progress: Training / epsilon: 0.8757100000033254 / score: -1.0
# step: 87316 / episode: 352 / progress: Training / epsilon: 0.8753700000033345 / score: -1.0
# step: 87378 / episode: 353 / progress: Training / epsilon: 0.8752460000033379 / score: -1.0
# step: 87980 / episode: 354 / progress: Training / epsilon: 0.8740420000033701 / score: 1.0
# step: 88042 / episode: 355 / progress: Training / epsilon: 0.8739180000033734 / score: -1.0
# step: 88428 / episode: 356 / progress: Training / epsilon: 0.873146000003394 / score: 0.0
# step: 88490 / episode: 357 / progress: Training / epsilon: 0.8730220000033974 / score: -1.0
# step: 88552 / episode: 358 / progress: Training / epsilon: 0.8728980000034007 / score: -1.0
# step: 88938 / episode: 359 / progress: Training / epsilon: 0.8721260000034213 / score: 0.0
# step: 89000 / episode: 360 / progress: Training / epsilon: 0.8720020000034246 / score: -1.0
# step: 89170 / episode: 361 / progress: Training / epsilon: 0.8716620000034337 / score: -1.0
# step: 89232 / episode: 362 / progress: Training / epsilon: 0.8715380000034371 / score: -1.0
# step: 89294 / episode: 363 / progress: Training / epsilon: 0.8714140000034404 / score: -1.0
# step: 89464 / episode: 364 / progress: Training / epsilon: 0.8710740000034495 / score: -1.0
# step: 89634 / episode: 365 / progress: Training / epsilon: 0.8707340000034586 / score: -1.0
# step: 89801 / episode: 366 / progress: Training / epsilon: 0.8704000000034675 / score: 5.0
# step: 89968 / episode: 367 / progress: Training / epsilon: 0.8700660000034764 / score: 5.0
# step: 90138 / episode: 368 / progress: Training / epsilon: 0.8697260000034855 / score: -1.0
# step: 90308 / episode: 369 / progress: Training / epsilon: 0.8693860000034946 / score: -1.0
# step: 90370 / episode: 370 / progress: Training / epsilon: 0.869262000003498 / score: -1.0
# step: 90432 / episode: 371 / progress: Training / epsilon: 0.8691380000035013 / score: -1.0
# step: 90818 / episode: 372 / progress: Training / epsilon: 0.8683660000035219 / score: 0.0
# step: 90988 / episode: 373 / progress: Training / epsilon: 0.868026000003531 / score: -1.0
# step: 91374 / episode: 374 / progress: Training / epsilon: 0.8672540000035517 / score: 0.0
# step: 91652 / episode: 375 / progress: Training / epsilon: 0.8666980000035666 / score: 0.0
# step: 91714 / episode: 376 / progress: Training / epsilon: 0.8665740000035699 / score: -1.0
# step: 92208 / episode: 377 / progress: Training / epsilon: 0.8655860000035963 / score: 1.0
# step: 92378 / episode: 378 / progress: Training / epsilon: 0.8652460000036054 / score: -1.0
# step: 92440 / episode: 379 / progress: Training / epsilon: 0.8651220000036087 / score: -1.0
# step: 92502 / episode: 380 / progress: Training / epsilon: 0.864998000003612 / score: -1.0
# step: 92780 / episode: 381 / progress: Training / epsilon: 0.8644420000036269 / score: 0.0
# step: 93058 / episode: 382 / progress: Training / epsilon: 0.8638860000036418 / score: 0.0
# step: 93336 / episode: 383 / progress: Training / epsilon: 0.8633300000036567 / score: 0.0
# step: 93398 / episode: 384 / progress: Training / epsilon: 0.86320600000366 / score: -1.0
# step: 93784 / episode: 385 / progress: Training / epsilon: 0.8624340000036806 / score: 0.0
# step: 93846 / episode: 386 / progress: Training / epsilon: 0.862310000003684 / score: -1.0
# step: 93908 / episode: 387 / progress: Training / epsilon: 0.8621860000036873 / score: -1.0
# step: 93967 / episode: 388 / progress: Training / epsilon: 0.8620680000036904 / score: 5.0
# step: 94245 / episode: 389 / progress: Training / epsilon: 0.8615120000037053 / score: 0.0
# step: 94631 / episode: 390 / progress: Training / epsilon: 0.860740000003726 / score: 0.0
# step: 94693 / episode: 391 / progress: Training / epsilon: 0.8606160000037293 / score: -1.0
# step: 94863 / episode: 392 / progress: Training / epsilon: 0.8602760000037384 / score: -1.0
# step: 94925 / episode: 393 / progress: Training / epsilon: 0.8601520000037417 / score: -1.0
# step: 94987 / episode: 394 / progress: Training / epsilon: 0.860028000003745 / score: -1.0
# step: 95265 / episode: 395 / progress: Training / epsilon: 0.8594720000037599 / score: 0.0
# step: 95435 / episode: 396 / progress: Training / epsilon: 0.859132000003769 / score: -1.0
# step: 95497 / episode: 397 / progress: Training / epsilon: 0.8590080000037723 / score: -1.0
# step: 95559 / episode: 398 / progress: Training / epsilon: 0.8588840000037756 / score: -1.0
# step: 95945 / episode: 399 / progress: Training / epsilon: 0.8581120000037963 / score: 0.0
# step: 96007 / episode: 400 / progress: Training / epsilon: 0.8579880000037996 / score: -1.0
# step: 96069 / episode: 401 / progress: Training / epsilon: 0.8578640000038029 / score: -1.0
# step: 96131 / episode: 402 / progress: Training / epsilon: 0.8577400000038062 / score: -1.0
# step: 96517 / episode: 403 / progress: Training / epsilon: 0.8569680000038269 / score: 0.0
# step: 96579 / episode: 404 / progress: Training / epsilon: 0.8568440000038302 / score: -1.0
# step: 97397 / episode: 405 / progress: Training / epsilon: 0.855208000003874 / score: 2.0
# step: 97567 / episode: 406 / progress: Training / epsilon: 0.8548680000038831 / score: -1.0
# step: 97626 / episode: 407 / progress: Training / epsilon: 0.8547500000038862 / score: 5.0
# step: 97688 / episode: 408 / progress: Training / epsilon: 0.8546260000038896 / score: -1.0
# step: 97858 / episode: 409 / progress: Training / epsilon: 0.8542860000038986 / score: -1.0
# ...
# step: 481996 / episode: 1670 / progress: Training / epsilon: 0.0999980000129777 / score: 5.0
# step: 483022 / episode: 1671 / progress: Training / epsilon: 0.0999980000129777 / score: 5.0
# step: 483940 / episode: 1672 / progress: Training / epsilon: 0.0999980000129777 / score: 5.0
# step: 484858 / episode: 1673 / progress: Training / epsilon: 0.0999980000129777 / score: 5.0
# step: 485776 / episode: 1674 / progress: Training / epsilon: 0.0999980000129777 / score: 5.0
# step: 486694 / episode: 1675 / progress: Training / epsilon: 0.0999980000129777 / score: 5.0
# step: 487612 / episode: 1676 / progress: Training / epsilon: 0.0999980000129777 / score: 5.0
# step: 488638 / episode: 1677 / progress: Training / epsilon: 0.0999980000129777 / score: 5.0
# step: 488700 / episode: 1678 / progress: Training / epsilon: 0.0999980000129777 / score: -1.0
# step: 489302 / episode: 1679 / progress: Training / epsilon: 0.0999980000129777 / score: 1.0
# step: 489576 / episode: 1680 / progress: Training / epsilon: 0.0999980000129777 / score: 5.0
# step: 489638 / episode: 1681 / progress: Training / epsilon: 0.0999980000129777 / score: -1.0
# step: 490664 / episode: 1682 / progress: Training / epsilon: 0.0999980000129777 / score: 5.0
# step: 491690 / episode: 1683 / progress: Training / epsilon: 0.0999980000129777 / score: 5.0
# step: 492716 / episode: 1684 / progress: Training / epsilon: 0.0999980000129777 / score: 5.0
# step: 493634 / episode: 1685 / progress: Training / epsilon: 0.0999980000129777 / score: 5.0
# step: 494128 / episode: 1686 / progress: Training / epsilon: 0.0999980000129777 / score: 1.0
# step: 494832 / episode: 1687 / progress: Training / epsilon: 0.0999980000129777 / score: 5.0
# step: 495750 / episode: 1688 / progress: Training / epsilon: 0.0999980000129777 / score: 5.0
# step: 496668 / episode: 1689 / progress: Training / epsilon: 0.0999980000129777 / score: 5.0
# step: 496730 / episode: 1690 / progress: Training / epsilon: 0.0999980000129777 / score: -1.0
# step: 497756 / episode: 1691 / progress: Training / epsilon: 0.0999980000129777 / score: 5.0
# step: 498782 / episode: 1692 / progress: Training / epsilon: 0.0999980000129777 / score: 5.0
# step: 499700 / episode: 1693 / progress: Training / epsilon: 0.0999980000129777 / score: 5.0
# step: 499759 / episode: 1694 / progress: Training / epsilon: 0.0999980000129777 / score: 5.0
# step: 500785 / episode: 1695 / progress: Training / epsilon: 0.0999980000129777 / score: 5.0
# step: 500955 / episode: 1696 / progress: Training / epsilon: 0.0999980000129777 / score: -1.0
# step: 501873 / episode: 1697 / progress: Training / epsilon: 0.0999980000129777 / score: 5.0
# step: 502255 / episode: 1698 / progress: Training / epsilon: 0.0999980000129777 / score: 5.0
# step: 502533 / episode: 1699 / progress: Training / epsilon: 0.0999980000129777 / score: 0.0
# step: 503237 / episode: 1700 / progress: Training / epsilon: 0.0999980000129777 / score: 5.0
# step: 504263 / episode: 1701 / progress: Training / epsilon: 0.0999980000129777 / score: 5.0
# step: 505289 / episode: 1702 / progress: Training / epsilon: 0.0999980000129777 / score: 5.0
# step: 506315 / episode: 1703 / progress: Training / epsilon: 0.0999980000129777 / score: 5.0
# step: 507233 / episode: 1704 / progress: Training / epsilon: 0.0999980000129777 / score: 5.0
# step: 508151 / episode: 1705 / progress: Training / epsilon: 0.0999980000129777 / score: 5.0
# step: 508753 / episode: 1706 / progress: Training / epsilon: 0.0999980000129777 / score: 1.0
# step: 509779 / episode: 1707 / progress: Training / epsilon: 0.0999980000129777 / score: 5.0
# step: 510597 / episode: 1708 / progress: Training / epsilon: 0.0999980000129777 / score: 2.0
# step: 511515 / episode: 1709 / progress: Training / epsilon: 0.0999980000129777 / score: 5.0
# step: 512541 / episode: 1710 / progress: Training / epsilon: 0.0999980000129777 / score: 5.0
# step: 513459 / episode: 1711 / progress: Training / epsilon: 0.0999980000129777 / score: 5.0
# step: 514377 / episode: 1712 / progress: Training / epsilon: 0.0999980000129777 / score: 5.0
# step: 515403 / episode: 1713 / progress: Training / epsilon: 0.0999980000129777 / score: 5.0
# step: 516322 / episode: 1714 / progress: Training / epsilon: 0.0999980000129777 / score: 5.0
# step: 517348 / episode: 1715 / progress: Training / epsilon: 0.0999980000129777 / score: 5.0
# step: 518266 / episode: 1716 / progress: Training / epsilon: 0.0999980000129777 / score: 5.0
# step: 518544 / episode: 1717 / progress: Training / epsilon: 0.0999980000129777 / score: 0.0
# step: 519570 / episode: 1718 / progress: Training / epsilon: 0.0999980000129777 / score: 5.0
# step: 520488 / episode: 1719 / progress: Training / epsilon: 0.0999980000129777 / score: 5.0
# step: 521198 / episode: 1720 / progress: Training / epsilon: 0.0999980000129777 / score: 2.0
# step: 522116 / episode: 1721 / progress: Training / epsilon: 0.0999980000129777 / score: 5.0
# step: 522934 / episode: 1722 / progress: Training / epsilon: 0.0999980000129777 / score: 2.0
# step: 523960 / episode: 1723 / progress: Training / epsilon: 0.0999980000129777 / score: 5.0
# step: 524986 / episode: 1724 / progress: Training / epsilon: 0.0999980000129777 / score: 5.0
# Model saved in file: saved_networks/2018-03-05_16_56_DuelingDQN/model.ckpt
# step: 526012 / episode: 1725 / progress: Testing / epsilon: 0 / score: 5.0
# step: 527038 / episode: 1726 / progress: Testing / epsilon: 0 / score: 5.0
# step: 527856 / episode: 1727 / progress: Testing / epsilon: 0 / score: 2.0
# step: 528238 / episode: 1728 / progress: Testing / epsilon: 0 / score: 5.0
# step: 528727 / episode: 1729 / progress: Testing / epsilon: 0 / score: 5.0
# step: 529005 / episode: 1730 / progress: Testing / epsilon: 0 / score: 0.0
# step: 529923 / episode: 1731 / progress: Testing / epsilon: 0 / score: 5.0
# step: 530841 / episode: 1732 / progress: Testing / epsilon: 0 / score: 5.0
# step: 531759 / episode: 1733 / progress: Testing / epsilon: 0 / score: 5.0
# step: 532677 / episode: 1734 / progress: Testing / epsilon: 0 / score: 5.0
# step: 532847 / episode: 1735 / progress: Testing / epsilon: 0 / score: -1.0
# step: 533341 / episode: 1736 / progress: Testing / epsilon: 0 / score: 1.0
# step: 534259 / episode: 1737 / progress: Testing / epsilon: 0 / score: 5.0
# step: 535071 / episode: 1738 / progress: Testing / epsilon: 0 / score: 5.0
# step: 535989 / episode: 1739 / progress: Testing / epsilon: 0 / score: 5.0
# step: 537015 / episode: 1740 / progress: Testing / epsilon: 0 / score: 5.0
# step: 537933 / episode: 1741 / progress: Testing / epsilon: 0 / score: 5.0
# step: 538637 / episode: 1742 / progress: Testing / epsilon: 0 / score: 5.0
# step: 539663 / episode: 1743 / progress: Testing / epsilon: 0 / score: 5.0
# step: 540481 / episode: 1744 / progress: Testing / epsilon: 0 / score: 2.0
# step: 541399 / episode: 1745 / progress: Testing / epsilon: 0 / score: 5.0
# step: 542425 / episode: 1746 / progress: Testing / epsilon: 0 / score: 5.0
# step: 543243 / episode: 1747 / progress: Testing / epsilon: 0 / score: 2.0
# step: 544161 / episode: 1748 / progress: Testing / epsilon: 0 / score: 5.0
# step: 545079 / episode: 1749 / progress: Testing / epsilon: 0 / score: 5.0
# step: 545357 / episode: 1750 / progress: Testing / epsilon: 0 / score: 0.0
# step: 546383 / episode: 1751 / progress: Testing / epsilon: 0 / score: 5.0
# step: 547093 / episode: 1752 / progress: Testing / epsilon: 0 / score: 2.0
# step: 548011 / episode: 1753 / progress: Testing / epsilon: 0 / score: 5.0
# step: 548715 / episode: 1754 / progress: Testing / epsilon: 0 / score: 5.0
# step: 549317 / episode: 1755 / progress: Testing / epsilon: 0 / score: 1.0
# step: 550343 / episode: 1756 / progress: Testing / epsilon: 0 / score: 5.0
# step: 550940 / episode: 1757 / progress: Testing / epsilon: 0 / score: 5.0
# step: 551218 / episode: 1758 / progress: Testing / epsilon: 0 / score: 0.0
# step: 551496 / episode: 1759 / progress: Testing / epsilon: 0 / score: 0.0
# step: 552200 / episode: 1760 / progress: Testing / epsilon: 0 / score: 5.0
# step: 553118 / episode: 1761 / progress: Testing / epsilon: 0 / score: 5.0
# step: 553504 / episode: 1762 / progress: Testing / epsilon: 0 / score: 0.0
# step: 553782 / episode: 1763 / progress: Testing / epsilon: 0 / score: 0.0
# step: 554164 / episode: 1764 / progress: Testing / epsilon: 0 / score: 5.0
# step: 555190 / episode: 1765 / progress: Testing / epsilon: 0 / score: 5.0
# step: 556002 / episode: 1766 / progress: Testing / epsilon: 0 / score: 5.0
# step: 556706 / episode: 1767 / progress: Testing / epsilon: 0 / score: 5.0
# step: 557624 / episode: 1768 / progress: Testing / epsilon: 0 / score: 5.0
# step: 557683 / episode: 1769 / progress: Testing / epsilon: 0 / score: 5.0
# step: 558601 / episode: 1770 / progress: Testing / epsilon: 0 / score: 5.0
# step: 558987 / episode: 1771 / progress: Testing / epsilon: 0 / score: 0.0
# step: 559481 / episode: 1772 / progress: Testing / epsilon: 0 / score: 1.0
# step: 560185 / episode: 1773 / progress: Testing / epsilon: 0 / score: 5.0
# step: 561003 / episode: 1774 / progress: Testing / epsilon: 0 / score: 2.0
# step: 561921 / episode: 1775 / progress: Testing / epsilon: 0 / score: 5.0
# step: 562523 / episode: 1776 / progress: Testing / epsilon: 0 / score: 1.0
# step: 563441 / episode: 1777 / progress: Testing / epsilon: 0 / score: 5.0
# step: 564467 / episode: 1778 / progress: Testing / epsilon: 0 / score: 5.0
# step: 564745 / episode: 1779 / progress: Testing / epsilon: 0 / score: 0.0
# step: 565455 / episode: 1780 / progress: Testing / epsilon: 0 / score: 2.0
# step: 565733 / episode: 1781 / progress: Testing / epsilon: 0 / score: 0.0
# step: 566659 / episode: 1782 / progress: Testing / epsilon: 0 / score: 3.0
# step: 567693 / episode: 1783 / progress: Testing / epsilon: 0 / score: 3.0
# step: 568397 / episode: 1784 / progress: Testing / epsilon: 0 / score: 5.0
# step: 569423 / episode: 1785 / progress: Testing / epsilon: 0 / score: 5.0
# step: 570341 / episode: 1786 / progress: Testing / epsilon: 0 / score: 5.0
# step: 570727 / episode: 1787 / progress: Testing / epsilon: 0 / score: 0.0
# step: 570786 / episode: 1788 / progress: Testing / epsilon: 0 / score: 5.0
# step: 571172 / episode: 1789 / progress: Testing / epsilon: 0 / score: 0.0
# step: 571990 / episode: 1790 / progress: Testing / epsilon: 0 / score: 2.0
# step: 572484 / episode: 1791 / progress: Testing / epsilon: 0 / score: 1.0
# step: 573518 / episode: 1792 / progress: Testing / epsilon: 0 / score: 3.0
# step: 574544 / episode: 1793 / progress: Testing / epsilon: 0 / score: 5.0
# step: 574603 / episode: 1794 / progress: Testing / epsilon: 0 / score: 5.0
# step: 575521 / episode: 1795 / progress: Testing / epsilon: 0 / score: 5.0
# step: 576439 / episode: 1796 / progress: Testing / epsilon: 0 / score: 5.0
# step: 576609 / episode: 1797 / progress: Testing / epsilon: 0 / score: -1.0
# step: 576887 / episode: 1798 / progress: Testing / epsilon: 0 / score: 0.0
# step: 577165 / episode: 1799 / progress: Testing / epsilon: 0 / score: 0.0
# step: 577335 / episode: 1800 / progress: Testing / epsilon: 0 / score: -1.0
# step: 578039 / episode: 1801 / progress: Testing / epsilon: 0 / score: 5.0
# step: 578209 / episode: 1802 / progress: Testing / epsilon: 0 / score: -1.0
# step: 578806 / episode: 1803 / progress: Testing / epsilon: 0 / score: 5.0
# step: 579086 / episode: 1804 / progress: Testing / epsilon: 0 / score: 2.0
# step: 579898 / episode: 1805 / progress: Testing / epsilon: 0 / score: 5.0
# step: 580068 / episode: 1806 / progress: Testing / epsilon: 0 / score: -1.0
# step: 580772 / episode: 1807 / progress: Testing / epsilon: 0 / score: 5.0
# step: 580834 / episode: 1808 / progress: Testing / epsilon: 0 / score: -1.0
# step: 581752 / episode: 1809 / progress: Testing / epsilon: 0 / score: 5.0
# step: 582670 / episode: 1810 / progress: Testing / epsilon: 0 / score: 5.0
# step: 583488 / episode: 1811 / progress: Testing / epsilon: 0 / score: 2.0
# step: 584406 / episode: 1812 / progress: Testing / epsilon: 0 / score: 5.0
# step: 584788 / episode: 1813 / progress: Testing / epsilon: 0 / score: 5.0
# step: 585814 / episode: 1814 / progress: Testing / epsilon: 0 / score: 5.0
# step: 586092 / episode: 1815 / progress: Testing / epsilon: 0 / score: 0.0
# step: 586904 / episode: 1816 / progress: Testing / epsilon: 0 / score: 5.0
# step: 587930 / episode: 1817 / progress: Testing / epsilon: 0 / score: 5.0
# step: 588848 / episode: 1818 / progress: Testing / epsilon: 0 / score: 5.0
# step: 589450 / episode: 1819 / progress: Testing / epsilon: 0 / score: 1.0
# step: 590368 / episode: 1820 / progress: Testing / epsilon: 0 / score: 5.0
# step: 591286 / episode: 1821 / progress: Testing / epsilon: 0 / score: 5.0
# step: 592204 / episode: 1822 / progress: Testing / epsilon: 0 / score: 5.0
# step: 593230 / episode: 1823 / progress: Testing / epsilon: 0 / score: 5.0
# step: 593400 / episode: 1824 / progress: Testing / epsilon: 0 / score: -1.0
# step: 593678 / episode: 1825 / progress: Testing / epsilon: 0 / score: 0.0
# step: 594596 / episode: 1826 / progress: Testing / epsilon: 0 / score: 5.0
# step: 594978 / episode: 1827 / progress: Testing / epsilon: 0 / score: 5.0
# step: 595896 / episode: 1828 / progress: Testing / epsilon: 0 / score: 5.0
# step: 596922 / episode: 1829 / progress: Testing / epsilon: 0 / score: 5.0
# step: 596981 / episode: 1830 / progress: Testing / epsilon: 0 / score: 5.0
# step: 598007 / episode: 1831 / progress: Testing / epsilon: 0 / score: 5.0
# step: 598174 / episode: 1832 / progress: Testing / epsilon: 0 / score: 5.0
# step: 598884 / episode: 1833 / progress: Testing / epsilon: 0 / score: 2.0
# step: 599810 / episode: 1834 / progress: Testing / epsilon: 0 / score: 3.0
# step: 600728 / episode: 1835 / progress: Testing / epsilon: 0 / score: 5.0
# step: 601754 / episode: 1836 / progress: Testing / epsilon: 0 / score: 5.0
# step: 602248 / episode: 1837 / progress: Testing / epsilon: 0 / score: 1.0
# step: 602310 / episode: 1838 / progress: Testing / epsilon: 0 / score: -1.0
# step: 603236 / episode: 1839 / progress: Testing / epsilon: 0 / score: 3.0
# step: 603514 / episode: 1840 / progress: Testing / epsilon: 0 / score: 0.0
# step: 604432 / episode: 1841 / progress: Testing / epsilon: 0 / score: 5.0
# step: 605350 / episode: 1842 / progress: Testing / epsilon: 0 / score: 5.0
# step: 605412 / episode: 1843 / progress: Testing / epsilon: 0 / score: -1.0
# step: 606446 / episode: 1844 / progress: Testing / epsilon: 0 / score: 3.0
# step: 607364 / episode: 1845 / progress: Testing / epsilon: 0 / score: 5.0
# step: 608282 / episode: 1846 / progress: Testing / epsilon: 0 / score: 5.0
# step: 608452 / episode: 1847 / progress: Testing / epsilon: 0 / score: -1.0
# step: 609478 / episode: 1848 / progress: Testing / epsilon: 0 / score: 5.0
# step: 610396 / episode: 1849 / progress: Testing / epsilon: 0 / score: 5.0
# step: 611314 / episode: 1850 / progress: Testing / epsilon: 0 / score: 5.0
# step: 612232 / episode: 1851 / progress: Testing / epsilon: 0 / score: 5.0
# step: 612294 / episode: 1852 / progress: Testing / epsilon: 0 / score: -1.0
# step: 613212 / episode: 1853 / progress: Testing / epsilon: 0 / score: 5.0
# step: 613271 / episode: 1854 / progress: Testing / epsilon: 0 / score: 5.0
# step: 614189 / episode: 1855 / progress: Testing / epsilon: 0 / score: 5.0
# step: 615107 / episode: 1856 / progress: Testing / epsilon: 0 / score: 5.0
# step: 616025 / episode: 1857 / progress: Testing / epsilon: 0 / score: 5.0
# step: 616943 / episode: 1858 / progress: Testing / epsilon: 0 / score: 5.0
# step: 617969 / episode: 1859 / progress: Testing / epsilon: 0 / score: 5.0
# step: 618355 / episode: 1860 / progress: Testing / epsilon: 0 / score: 0.0
# step: 619381 / episode: 1861 / progress: Testing / epsilon: 0 / score: 5.0
# step: 620299 / episode: 1862 / progress: Testing / epsilon: 0 / score: 5.0
# step: 621217 / episode: 1863 / progress: Testing / epsilon: 0 / score: 5.0
# step: 621387 / episode: 1864 / progress: Testing / epsilon: 0 / score: -1.0
# step: 622413 / episode: 1865 / progress: Testing / epsilon: 0 / score: 5.0
# step: 623331 / episode: 1866 / progress: Testing / epsilon: 0 / score: 5.0
# step: 624357 / episode: 1867 / progress: Testing / epsilon: 0 / score: 5.0
# Finished!!

# %%
env.close()
